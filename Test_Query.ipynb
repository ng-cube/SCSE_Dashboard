# %%
import pymongo

# %%
list_of_keywords_with_names=[{'keyword': 'Computer Science and Engineering', 'names': ['Wai Kin Adams Kong', 'Luu Anh Tuan', 'Anupam Chattopadhyay', 'Anwitaman Datta', 'Arvind Easwaran', 'Vun Chan Hua, Nicholas', 'Kwoh Chee Keong', 'Yeo Chai Kiat', 'Miao Chun Yan', 'Douglas Leslie Maskell', 'Deepu Rajan', 'Li Fang', 'Quek Hiok Chai', 'Zheng Jianmin', 'Chia Liang Tien', 'A S Madhukumar', 'Chan Syin', 'Hui Siu Cheung', 'Lam Siew Kei', 'Sourav Saha Bhowmick', 'Alexei Sourin', 'Huang Shell Ying', 'Cham Tat Jen', 'Thambipillai Srikanthan', 'Goh Wooi Boon', 'Wentong Cai', 'Tang Xueyan', 'Ong Yew Soon', 'Wee Keong NG', 'Li Boyang', 'Erik Cambria', 'Chen Change Loy', 'Ong Chin Ann', 'Dusit Niyato', 'Lee Bu Sung', 'Cong Gao', 'Lin Guosheng', 'Zhang Hanwang', 'Oh Hong Lye', 'Zhao Jun', 'Tay Kian Boon', 'Lam Kwok Yan', 'Li Mo', 'Liu Weichen', 'Qian Kemao', 'Mohamed M. Sabry', 'Owen Noel Newton Fernando', 'Lin Shang-Wei', 'Pan, Sinno Jialin', 'Luo Siqiang', 'Smitha K G', 'Joty Shafiq Rayhan', 'Tan Rui', 'Zhang Tianwei', 'Wang Wenya', 'Lin Weisi', 'Lin Weisi', 'Pan Xingang', 'Liu Yang', 'Liu Yang', 'Wen Yonggang', 'Wen Yonggang', 'He Ying', 'He Ying', 'Li Yi', 'Li Yi', 'Ke Yiping, Kelly', 'Loke Yuan Ren', 'Zinovi Rabinovich', 'Liu Ziwei']}, {'keyword': 'Smart Cities', 'names': ['Wai Kin Adams Kong', 'Chng Eng Siong', 'Alexei Sourin', 'Ong Yew Soon', 'Bo An', 'Bo An', 'Wei Yang Bryan Lim', 'Cong Gao', 'Lam Kwok Yan', 'Lu Shijian']}, {'keyword': 'Disruptive Technology and Materials', 'names': ['Wai Kin Adams Kong', 'Luu Anh Tuan', 'Alexei Sourin', 'Huang Shell Ying', 'Cham Tat Jen', 'Thambipillai Srikanthan', 'Goh Wooi Boon', 'Wentong Cai', 'Tang Xueyan', 'Ong Yew Soon', 'Wee Keong NG', 'Sun Aixin', 'Cong Gao', 'Lin Guosheng', 'Yu Han', 'Zhang Hanwang', 'Oh Hong Lye', 'Josephine Chong', 'Luo Jun', 'Zhao Jun', 'Tay Kian Boon']}, {'keyword': 'Medical Technology', 'names': ['Wai Kin Adams Kong', 'Luu Anh Tuan', 'Alexei Sourin', 'Huang Shell Ying', 'Cham Tat Jen', 'Thambipillai Srikanthan', 'Goh Wooi Boon', 'Wentong Cai', 'Tang Xueyan']}, {'keyword': 'Smart Nation', 'names': ['Wai Kin Adams Kong', 'Luu Anh Tuan', 'Alexei Sourin', 'Huang Shell Ying', 'Cham Tat Jen', 'Thambipillai Srikanthan', 'Goh Wooi Boon', 'Wentong Cai', 'Tang Xueyan', 'Ong Yew Soon', 'Wee Keong NG', 'Sun Aixin', 'Bo An', 'Li Boyang', 'Cong Gao', 'Lin Guosheng', 'Yu Han', 'Zhang Hanwang', 'Oh Hong Lye', 'Josephine Chong', 'Luo Jun', 'Zhao Jun', 'Tay Kian Boon', 'Lam Kwok Yan', 'Li Mo', 'Liu Weichen', 'Lu Shijian', 'Pan, Sinno Jialin', 'Luo Siqiang', 'Smitha K G', 'Joty Shafiq Rayhan', 'Siyuan Liu', 'Tan Rui', 'Zhang Tianwei', 'Vidya Sudarshan']}, {'keyword': 'Electrical and Electronic Engineering', 'names': ['Anupam Chattopadhyay', 'Vun Chan Hua, Nicholas', 'Yeo Chai Kiat', 'Douglas Leslie Maskell', 'Deepu Rajan', 'Deepu Rajan', 'Quek Hiok Chai', 'A S Madhukumar', 'Lam Siew Kei', 'Thambipillai Srikanthan', 'Goh Wooi Boon', 'Dusit Niyato', 'Zhang Hanwang', 'Zhao Jun', 'Qian Kemao', 'Mohamed M. Sabry', 'Smitha K G', 'Lin Weisi', 'Loke Yuan Ren']}, {'keyword': 'Microelectronics & Applications', 'names': ['Anupam Chattopadhyay', 'Smitha K G']}, {'keyword': 'Nanotechnology & Nano-Science', 'names': ['Anupam Chattopadhyay', 'Mohamed M. Sabry']}, {'keyword': 'Security Studies & Policy Issues', 'names': ['Anupam Chattopadhyay', 'Wee Keong NG', 'Lam Kwok Yan']}, {'keyword': 'Computing Hardware and Architecture', 'names': ['Anupam Chattopadhyay', 'Arvind Easwaran', 'Vun Chan Hua, Nicholas', 'Douglas Leslie Maskell', 'Lam Siew Kei', 'Thambipillai Srikanthan', 'Dmitrii Ustiugov', 'Liu Weichen', 'Mohamed M. Sabry']}, {'keyword': 'Hardware and Embedded Systems', 'names': ['Anupam Chattopadhyay', 'Douglas Leslie Maskell', 'Lam Siew Kei', 'Thambipillai Srikanthan', 'Luo Jun', 'Liu Weichen', 'Mohamed M. Sabry']}, {'keyword': 'Quantum Technology', 'names': ['Anupam Chattopadhyay', 'Anwitaman Datta', 'Arvind Easwaran', 'Vun Chan Hua, Nicholas', 'Kwoh Chee Keong', 'Yeo Chai Kiat', 'Lau Chiew Tong']}, {'keyword': 'Parallel and Distributed Computing', 'names': ['Anwitaman Datta', 'Seah Hock Soon', 'Huang Shell Ying', 'Wentong Cai', 'Tang Xueyan', 'Wei Yang Bryan Lim', 'Dmitrii Ustiugov', 'Lee Bu Sung', 'Yu Han']}, {'keyword': 'Info-Communication Technology', 'names': ['Vun Chan Hua, Nicholas', 'Yeo Chai Kiat', 'Lau Chiew Tong', 'Miao Chun Yan', 'Deepu Rajan', 'Deepu Rajan', 'Chia Liang Tien', 'A S Madhukumar', 'Chan Syin', 'Hui Siu Cheung', 'Huang Shell Ying', 'Cham Tat Jen', 'Wee Keong NG', 'Lee Bu Sung', 'Lam Kwok Yan', 'Owen Noel Newton Fernando', 'Tan Rui', 'Wen Yonggang']}, {'keyword': 'Internet & Communications', 'names': ['Vun Chan Hua, Nicholas', 'Yeo Chai Kiat', 'Lau Chiew Tong', 'Miao Chun Yan', 'Li Fang', 'Chia Liang Tien', 'A S Madhukumar', 'Chan Syin', 'Hui Siu Cheung', 'Wee Keong NG', 'Lee Bu Sung', 'Li Mo', 'Tan Rui', 'Wen Yonggang']}, {'keyword': 'Biomedical Sciences & Life Sciences', 'names': ['Kwoh Chee Keong', 'Quek Hiok Chai', 'Sourav Saha Bhowmick']}, {'keyword': 'Interface of Biology & Engineering (Engineering in Biology)', 'names': ['Kwoh Chee Keong']}, {'keyword': 'Mathematics', 'names': ['Kwoh Chee Keong', 'Zheng Jianmin', 'Hui Siu Cheung', 'Zhang Hanwang', 'Zhao Jun', 'Tay Kian Boon', 'Luke Ong （翁之昊）', 'Loke Yuan Ren']}, {'keyword': 'Systems and Engineering Management', 'names': ['Kwoh Chee Keong', 'Huang Shell Ying', 'Mohamed M. Sabry']}, {'keyword': 'Interactive Digital Media', 'names': ['Yeo Chai Kiat', 'Miao Chun Yan', 'Deepu Rajan', 'Deepu Rajan', 'Zheng Jianmin', 'Chia Liang Tien', 'A S Madhukumar', 'Chan Syin', 'Hui Siu Cheung', 'Alexei Sourin', 'Cham Tat Jen', 'Goh Wooi Boon', 'Wee Keong NG', 'Zhang Hanwang', 'Qian Kemao', 'Owen Noel Newton Fernando', 'Loke Yuan Ren']}, {'keyword': 'Computer Networks and Communications', 'names': ['Yeo Chai Kiat', 'Lau Chiew Tong', 'A S Madhukumar', 'Ong Chin Ann', 'Dusit Niyato', 'Lee Bu Sung', 'Luo Jun', 'Zhao Jun', 'Li Mo', 'Tan Rui']}, {'keyword': 'Artificial and Augmented Intelligence', 'names': ['Miao Chun Yan', 'Chng Eng Siong', 'Jagath Chandana Rajapakse', 'Bo An', 'Wei Yang Bryan Lim', 'Erik Cambria', 'Guan Cuntai', 'Cong Gao', 'Yu Han', 'Luke Ong （翁之昊）', 'Lin Weisi', 'Zhang Jie', 'Shen Zhiqi']}, {'keyword': 'Disrupting the Future of Industry and Manufacturing', 'names': ['Miao Chun Yan', 'Douglas Leslie Maskell', 'Deepu Rajan', 'Ong Yew Soon', 'Wee Keong NG', 'Sun Aixin', 'Lu Shijian', 'Pan, Sinno Jialin', 'Luo Siqiang', 'Smitha K G', 'Joty Shafiq Rayhan', 'Siyuan Liu', 'Tan Rui', 'Zhang Tianwei', 'Vidya Sudarshan']}, {'keyword': 'Frailty: Use of AI-R Tool for Rehabilitation at Home Reducing the Need for Hospital Physiotherapy', 'names': ['Miao Chun Yan', 'Douglas Leslie Maskell', 'Deepu Rajan']}, {'keyword': 'Energy', 'names': ['Douglas Leslie Maskell', 'Zhao Jun', 'Tan Rui']}, {'keyword': 'Computational Intelligence', 'names': ['Chng Eng Siong', 'Jagath Chandana Rajapakse', 'Sun Aixin', 'Bo An', 'Erik Cambria', 'Guan Cuntai', 'Yu Han', 'Siyuan Liu', 'Wei Ying', 'Zhang Jie', 'Shen Zhiqi']}, {'keyword': 'Speech Recognition', 'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']}, {'keyword': 'Speech Enhancement', 'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']}, {'keyword': 'Speech Signal Processing', 'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']}, {'keyword': 'Speaker Speech Separation', 'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']}, {'keyword': 'Audio Processing', 'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']}, {'keyword': 'Speaker Diarization', 'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']}, {'keyword': 'Financial Engineering & Risk Management', 'names': ['Quek Hiok Chai']}, {'keyword': 'Machines & Systems', 'names': ['Quek Hiok Chai', 'Goh Wooi Boon', 'Mohamed M. Sabry', 'Smitha K G', 'Loke Yuan Ren']}, {'keyword': 'Computer Vision and Sensing', 'names': ['Seah Hock Soon', 'Ong Chin Ann', 'Luo Jun', 'Lu Shijian', 'Shen Zhiqi']}, {'keyword': 'Graphics and Interactive Computing', 'names': ['Seah Hock Soon', 'Alexei Sourin', 'Yu Han', 'Owen Noel Newton Fernando', 'Lu Shijian', 'Shen Zhiqi']}, {'keyword': 'Animation', 'names': ['Seah Hock Soon']}, {'keyword': 'Interactive Media', 'names': ['Seah Hock Soon']}, {'keyword': 'Biomedical Engineering', 'names': ['Jagath Chandana Rajapakse']}, {'keyword': 'Information Sciences and Systems', 'names': ['Jagath Chandana Rajapakse', 'Sun Aixin', 'Bo An', 'Long Cheng', 'Erik Cambria', 'Yu Han']}, {'keyword': 'Healthy Brain Ageing', 'names': ['Jagath Chandana Rajapakse']}, {'keyword': 'Mental Health', 'names': ['Jagath Chandana Rajapakse']}, {'keyword': 'Neuroscience', 'names': ['Jagath Chandana Rajapakse', 'Lu Shijian']}, {'keyword': 'Biomedical Informatics and Data Science', 'names': ['Jagath Chandana Rajapakse', 'Guan Cuntai', 'Wei Ying']}, {'keyword': 'Computational and Systems Biology', 'names': ['Jagath Chandana Rajapakse', 'Zheng Jianmin', 'Chia Liang Tien', 'A S Madhukumar', 'Chan Syin', 'Hui Siu Cheung', 'Lam Siew Kei', 'Sourav Saha Bhowmick']}, {'keyword': 'Brain Image Analysis', 'names': ['Jagath Chandana Rajapakse', 'Zheng Jianmin', 'Chia Liang Tien', 'A S Madhukumar', 'Chan Syin', 'Hui Siu Cheung', 'Lam Siew Kei', 'Sourav Saha Bhowmick']}, {'keyword': 'Mechanical & Manufacturing Engineering', 'names': ['Zheng Jianmin', 'Qian Kemao']}, {'keyword': 'Art, Design and Media', 'names': ['Zheng Jianmin', 'Sourav Saha Bhowmick', 'Owen Noel Newton Fernando']}, {'keyword': 'Sociology', 'names': ['Sourav Saha Bhowmick', 'Cong Gao']}, {'keyword': 'EdTech & Science Communication', 'names': ['Alexei Sourin', 'Huang Shell Ying', 'Cham Tat Jen', 'Thambipillai Srikanthan', 'Goh Wooi Boon', 'Wentong Cai', 'Tang Xueyan']}, {'keyword': 'Urban Planning and Human Centered Design', 'names': ['Alexei Sourin', 'Huang Shell Ying', 'Cham Tat Jen', 'Thambipillai Srikanthan', 'Goh Wooi Boon', 'Wentong Cai', 'Tang Xueyan']}, {'keyword': 'Business and Management', 'names': ['Huang Shell Ying']}, {'keyword': 'Cyber Security and Forensics', 'names': ['Thambipillai Srikanthan', 'Wee Keong NG', 'Lam Kwok Yan', 'Lin Shang-Wei', 'Siyuan Liu', 'Liu Yang']}, {'keyword': 'Robotics and Intelligent Systems', 'names': ['Bo An']}, {'keyword': 'Economics', 'names': ['Bo An', 'Lu Shijian']}, {'keyword': 'Digital Economy', 'names': ['Bo An', 'Li Boyang', 'Lu Shijian', 'Pan, Sinno Jialin', 'Luo Siqiang', 'Smitha K G', 'Joty Shafiq Rayhan', 'Siyuan Liu', 'Tan Rui', 'Zhang Tianwei', 'Vidya Sudarshan']}, {'keyword': 'Technoethics', 'names': ['Bo An', 'Li Boyang']}, {'keyword': 'Internet of Things', 'names': ['Wei Yang Bryan Lim', 'Luo Jun', 'Li Mo', 'Siyuan Liu']}, {'keyword': 'Edge Intelligence', 'names': ['Wei Yang Bryan Lim']}, {'keyword': 'Data Management', 'names': ['Long Cheng', 'Cong Gao', 'Lin Guosheng', 'Yu Han', 'Zhang Hanwang', 'Oh Hong Lye', 'Josephine Chong', 'Luo Jun', 'Zhao Jun', 'Tay Kian Boon']}, {'keyword': 'Data Mining', 'names': ['Long Cheng', 'Cong Gao', 'Lin Guosheng', 'Yu Han', 'Zhang Hanwang', 'Oh Hong Lye', 'Josephine Chong', 'Luo Jun', 'Zhao Jun', 'Tay Kian Boon']}, {'keyword': 'Machine-Person Interoperability', 'names': ['Erik Cambria', 'Loke Yuan Ren']}, {'keyword': 'Affective Computing', 'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']}, {'keyword': 'Sentiment Analysis', 'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']}, {'keyword': 'Commonsense Reasoning', 'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']}, {'keyword': 'Neurosymbolic AI', 'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']}, {'keyword': 'Brain Machine Interface', 'names': ['Guan Cuntai', 'Smitha K G']}, {'keyword': 'Machine Learning', 'names': ['Guan Cuntai', 'Wei Ying', 'Ke Yiping, Kelly', 'Loke Yuan Ren', 'Zhang Jie', 'Zinovi Rabinovich', 'Liu Ziwei']}, {'keyword': 'Neural Signal Processing', 'names': ['Guan Cuntai']}, {'keyword': 'Medical Image Analysis', 'names': ['Guan Cuntai']}, {'keyword': 'Cloud Computing', 'names': ['Dmitrii Ustiugov', 'Dusit Niyato', 'Lee Bu Sung']}, {'keyword': 'Distributed Operating Systems', 'names': ['Dmitrii Ustiugov', 'Dusit Niyato', 'Lee Bu Sung']}, {'keyword': 'Serverless Computing', 'names': ['Dmitrii Ustiugov', 'Dusit Niyato', 'Lee Bu Sung']}, {'keyword': 'Social Physics', 'names': ['Cong Gao', 'Lin Guosheng', 'Yu Han', 'Zhang Hanwang', 'Oh Hong Lye', 'Josephine Chong', 'Luo Jun', 'Zhao Jun', 'Tay Kian Boon']}, {'keyword': 'Data Science', 'names': ['Cong Gao', 'Lin Guosheng', 'Yu Han', 'Zhang Hanwang', 'Oh Hong Lye', 'Josephine Chong', 'Luo Jun', 'Zhao Jun', 'Tay Kian Boon']}, {'keyword': 'Language & Communication', 'names': ['Zhang Hanwang']}, {'keyword': 'Science, Technology and Society', 'names': ['Zhao Jun']}, {'keyword': 'Responsible Banking and Investment', 'names': ['Lam Kwok Yan', 'Li Mo', 'Liu Weichen']}, {'keyword': 'Bayesian Statistical Probabilistic Programming', 'names': ['Luke Ong （翁之昊）', 'Qian Kemao', 'Mohamed M. Sabry', 'Owen Noel Newton Fernando', 'Lin Shang-Wei']}, {'keyword': 'Programming Languages', 'names': ['Luke Ong （翁之昊）', 'Qian Kemao', 'Mohamed M. Sabry', 'Owen Noel Newton Fernando', 'Lin Shang-Wei']}, {'keyword': 'Semantics of Computation', 'names': ['Luke Ong （翁之昊）', 'Qian Kemao', 'Mohamed M. Sabry', 'Owen Noel Newton Fernando', 'Lin Shang-Wei']}, {'keyword': 'Verification and Formal Methods', 'names': ['Luke Ong （翁之昊）', 'Qian Kemao', 'Mohamed M. Sabry', 'Owen Noel Newton Fernando', 'Lin Shang-Wei']}, {'keyword': 'Logic and Algorithms', 'names': ['Luke Ong （翁之昊）', 'Qian Kemao', 'Mohamed M. Sabry', 'Owen Noel Newton Fernando', 'Lin Shang-Wei']}, {'keyword': 'Security', 'names': ['Luke Ong （翁之昊）', 'Qian Kemao', 'Mohamed M. Sabry', 'Owen Noel Newton Fernando', 'Lin Shang-Wei']}, {'keyword': 'Physics', 'names': ['Qian Kemao']}, {'keyword': 'Image and Video Analytics', 'names': ['Lu Shijian', 'Pan, Sinno Jialin', 'Luo Siqiang', 'Smitha K G', 'Joty Shafiq Rayhan', 'Siyuan Liu', 'Tan Rui', 'Zhang Tianwei', 'Vidya Sudarshan']}, {'keyword': 'Neurotechnology', 'names': ['Lu Shijian', 'Pan, Sinno Jialin', 'Luo Siqiang', 'Smitha K G', 'Joty Shafiq Rayhan', 'Siyuan Liu', 'Tan Rui', 'Zhang Tianwei', 'Vidya Sudarshan']}, {'keyword': 'Linguistics and Multilingual Studies', 'names': ['Joty Shafiq Rayhan']}, {'keyword': 'Ageing', 'names': ['Siyuan Liu', 'Shen Zhiqi']}, {'keyword': 'Artificial Intelligence for Drug Discovery', 'names': ['Wei Ying', 'Ke Yiping, Kelly', 'Loke Yuan Ren']}, {'keyword': 'Artificial Intelligence', 'names': ['Zhang Jie', 'Zinovi Rabinovich', 'Liu Ziwei', 'Shen Zhiqi']}, {'keyword': 'User Modeling', 'names': ['Zhang Jie', 'Zinovi Rabinovich', 'Liu Ziwei']}, {'keyword': 'Trust and Preference', 'names': ['Zhang Jie', 'Zinovi Rabinovich', 'Liu Ziwei']}, {'keyword': 'Software Agent Technology', 'names': ['Shen Zhiqi']}]

# %%
list_of_keywords_with_names
# Out:
# [{'keyword': 'Computer Science and Engineering',
#   'names': ['Wai Kin Adams Kong',
#    'Luu Anh Tuan',
#    'Anupam Chattopadhyay',
#    'Anwitaman Datta',
#    'Arvind Easwaran',
#    'Vun Chan Hua, Nicholas',
#    'Kwoh Chee Keong',
#    'Yeo Chai Kiat',
#    'Miao Chun Yan',
#    'Douglas Leslie Maskell',
#    'Deepu Rajan',
#    'Li Fang',
#    'Quek Hiok Chai',
#    'Zheng Jianmin',
#    'Chia Liang Tien',
#    'A S Madhukumar',
#    'Chan Syin',
#    'Hui Siu Cheung',
#    'Lam Siew Kei',
#    'Sourav Saha Bhowmick',
#    'Alexei Sourin',
#    'Huang Shell Ying',
#    'Cham Tat Jen',
#    'Thambipillai Srikanthan',
#    'Goh Wooi Boon',
#    'Wentong Cai',
#    'Tang Xueyan',
#    'Ong Yew Soon',
#    'Wee Keong NG',
#    'Li Boyang',
#    'Erik Cambria',
#    'Chen Change Loy',
#    'Ong Chin Ann',
#    'Dusit Niyato',
#    'Lee Bu Sung',
#    'Cong Gao',
#    'Lin Guosheng',
#    'Zhang Hanwang',
#    'Oh Hong Lye',
#    'Zhao Jun',
#    'Tay Kian Boon',
#    'Lam Kwok Yan',
#    'Li Mo',
#    'Liu Weichen',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Owen Noel Newton Fernando',
#    'Lin Shang-Wei',
#    'Pan, Sinno Jialin',
#    'Luo Siqiang',
#    'Smitha K G',
#    'Joty Shafiq Rayhan',
#    'Tan Rui',
#    'Zhang Tianwei',
#    'Wang Wenya',
#    'Lin Weisi',
#    'Lin Weisi',
#    'Pan Xingang',
#    'Liu Yang',
#    'Liu Yang',
#    'Wen Yonggang',
#    'Wen Yonggang',
#    'He Ying',
#    'He Ying',
#    'Li Yi',
#    'Li Yi',
#    'Ke Yiping, Kelly',
#    'Loke Yuan Ren',
#    'Zinovi Rabinovich',
#    'Liu Ziwei']},
#  {'keyword': 'Smart Cities',
#   'names': ['Wai Kin Adams Kong',
#    'Chng Eng Siong',
#    'Alexei Sourin',
#    'Ong Yew Soon',
#    'Bo An',
#    'Bo An',
#    'Wei Yang Bryan Lim',
#    'Cong Gao',
#    'Lam Kwok Yan',
#    'Lu Shijian']},
#  {'keyword': 'Disruptive Technology and Materials',
#   'names': ['Wai Kin Adams Kong',
#    'Luu Anh Tuan',
#    'Alexei Sourin',
#    'Huang Shell Ying',
#    'Cham Tat Jen',
#    'Thambipillai Srikanthan',
#    'Goh Wooi Boon',
#    'Wentong Cai',
#    'Tang Xueyan',
#    'Ong Yew Soon',
#    'Wee Keong NG',
#    'Sun Aixin',
#    'Cong Gao',
#    'Lin Guosheng',
#    'Yu Han',
#    'Zhang Hanwang',
#    'Oh Hong Lye',
#    'Josephine Chong',
#    'Luo Jun',
#    'Zhao Jun',
#    'Tay Kian Boon']},
#  {'keyword': 'Medical Technology',
#   'names': ['Wai Kin Adams Kong',
#    'Luu Anh Tuan',
#    'Alexei Sourin',
#    'Huang Shell Ying',
#    'Cham Tat Jen',
#    'Thambipillai Srikanthan',
#    'Goh Wooi Boon',
#    'Wentong Cai',
#    'Tang Xueyan']},
#  {'keyword': 'Smart Nation',
#   'names': ['Wai Kin Adams Kong',
#    'Luu Anh Tuan',
#    'Alexei Sourin',
#    'Huang Shell Ying',
#    'Cham Tat Jen',
#    'Thambipillai Srikanthan',
#    'Goh Wooi Boon',
#    'Wentong Cai',
#    'Tang Xueyan',
#    'Ong Yew Soon',
#    'Wee Keong NG',
#    'Sun Aixin',
#    'Bo An',
#    'Li Boyang',
#    'Cong Gao',
#    'Lin Guosheng',
#    'Yu Han',
#    'Zhang Hanwang',
#    'Oh Hong Lye',
#    'Josephine Chong',
#    'Luo Jun',
#    'Zhao Jun',
#    'Tay Kian Boon',
#    'Lam Kwok Yan',
#    'Li Mo',
#    'Liu Weichen',
#    'Lu Shijian',
#    'Pan, Sinno Jialin',
#    'Luo Siqiang',
#    'Smitha K G',
#    'Joty Shafiq Rayhan',
#    'Siyuan Liu',
#    'Tan Rui',
#    'Zhang Tianwei',
#    'Vidya Sudarshan']},
#  {'keyword': 'Electrical and Electronic Engineering',
#   'names': ['Anupam Chattopadhyay',
#    'Vun Chan Hua, Nicholas',
#    'Yeo Chai Kiat',
#    'Douglas Leslie Maskell',
#    'Deepu Rajan',
#    'Deepu Rajan',
#    'Quek Hiok Chai',
#    'A S Madhukumar',
#    'Lam Siew Kei',
#    'Thambipillai Srikanthan',
#    'Goh Wooi Boon',
#    'Dusit Niyato',
#    'Zhang Hanwang',
#    'Zhao Jun',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Smitha K G',
#    'Lin Weisi',
#    'Loke Yuan Ren']},
#  {'keyword': 'Microelectronics & Applications',
#   'names': ['Anupam Chattopadhyay', 'Smitha K G']},
#  {'keyword': 'Nanotechnology & Nano-Science',
#   'names': ['Anupam Chattopadhyay', 'Mohamed M. Sabry']},
#  {'keyword': 'Security Studies & Policy Issues',
#   'names': ['Anupam Chattopadhyay', 'Wee Keong NG', 'Lam Kwok Yan']},
#  {'keyword': 'Computing Hardware and Architecture',
#   'names': ['Anupam Chattopadhyay',
#    'Arvind Easwaran',
#    'Vun Chan Hua, Nicholas',
#    'Douglas Leslie Maskell',
#    'Lam Siew Kei',
#    'Thambipillai Srikanthan',
#    'Dmitrii Ustiugov',
#    'Liu Weichen',
#    'Mohamed M. Sabry']},
#  {'keyword': 'Hardware and Embedded Systems',
#   'names': ['Anupam Chattopadhyay',
#    'Douglas Leslie Maskell',
#    'Lam Siew Kei',
#    'Thambipillai Srikanthan',
#    'Luo Jun',
#    'Liu Weichen',
#    'Mohamed M. Sabry']},
#  {'keyword': 'Quantum Technology',
#   'names': ['Anupam Chattopadhyay',
#    'Anwitaman Datta',
#    'Arvind Easwaran',
#    'Vun Chan Hua, Nicholas',
#    'Kwoh Chee Keong',
#    'Yeo Chai Kiat',
#    'Lau Chiew Tong']},
#  {'keyword': 'Parallel and Distributed Computing',
#   'names': ['Anwitaman Datta',
#    'Seah Hock Soon',
#    'Huang Shell Ying',
#    'Wentong Cai',
#    'Tang Xueyan',
#    'Wei Yang Bryan Lim',
#    'Dmitrii Ustiugov',
#    'Lee Bu Sung',
#    'Yu Han']},
#  {'keyword': 'Info-Communication Technology',
#   'names': ['Vun Chan Hua, Nicholas',
#    'Yeo Chai Kiat',
#    'Lau Chiew Tong',
#    'Miao Chun Yan',
#    'Deepu Rajan',
#    'Deepu Rajan',
#    'Chia Liang Tien',
#    'A S Madhukumar',
#    'Chan Syin',
#    'Hui Siu Cheung',
#    'Huang Shell Ying',
#    'Cham Tat Jen',
#    'Wee Keong NG',
#    'Lee Bu Sung',
#    'Lam Kwok Yan',
#    'Owen Noel Newton Fernando',
#    'Tan Rui',
#    'Wen Yonggang']},
#  {'keyword': 'Internet & Communications',
#   'names': ['Vun Chan Hua, Nicholas',
#    'Yeo Chai Kiat',
#    'Lau Chiew Tong',
#    'Miao Chun Yan',
#    'Li Fang',
#    'Chia Liang Tien',
#    'A S Madhukumar',
#    'Chan Syin',
#    'Hui Siu Cheung',
#    'Wee Keong NG',
#    'Lee Bu Sung',
#    'Li Mo',
#    'Tan Rui',
#    'Wen Yonggang']},
#  {'keyword': 'Biomedical Sciences & Life Sciences',
#   'names': ['Kwoh Chee Keong', 'Quek Hiok Chai', 'Sourav Saha Bhowmick']},
#  {'keyword': 'Interface of Biology & Engineering (Engineering in Biology)',
#   'names': ['Kwoh Chee Keong']},
#  {'keyword': 'Mathematics',
#   'names': ['Kwoh Chee Keong',
#    'Zheng Jianmin',
#    'Hui Siu Cheung',
#    'Zhang Hanwang',
#    'Zhao Jun',
#    'Tay Kian Boon',
#    'Luke Ong （翁之昊）',
#    'Loke Yuan Ren']},
#  {'keyword': 'Systems and Engineering Management',
#   'names': ['Kwoh Chee Keong', 'Huang Shell Ying', 'Mohamed M. Sabry']},
#  {'keyword': 'Interactive Digital Media',
#   'names': ['Yeo Chai Kiat',
#    'Miao Chun Yan',
#    'Deepu Rajan',
#    'Deepu Rajan',
#    'Zheng Jianmin',
#    'Chia Liang Tien',
#    'A S Madhukumar',
#    'Chan Syin',
#    'Hui Siu Cheung',
#    'Alexei Sourin',
#    'Cham Tat Jen',
#    'Goh Wooi Boon',
#    'Wee Keong NG',
#    'Zhang Hanwang',
#    'Qian Kemao',
#    'Owen Noel Newton Fernando',
#    'Loke Yuan Ren']},
#  {'keyword': 'Computer Networks and Communications',
#   'names': ['Yeo Chai Kiat',
#    'Lau Chiew Tong',
#    'A S Madhukumar',
#    'Ong Chin Ann',
#    'Dusit Niyato',
#    'Lee Bu Sung',
#    'Luo Jun',
#    'Zhao Jun',
#    'Li Mo',
#    'Tan Rui']},
#  {'keyword': 'Artificial and Augmented Intelligence',
#   'names': ['Miao Chun Yan',
#    'Chng Eng Siong',
#    'Jagath Chandana Rajapakse',
#    'Bo An',
#    'Wei Yang Bryan Lim',
#    'Erik Cambria',
#    'Guan Cuntai',
#    'Cong Gao',
#    'Yu Han',
#    'Luke Ong （翁之昊）',
#    'Lin Weisi',
#    'Zhang Jie',
#    'Shen Zhiqi']},
#  {'keyword': 'Disrupting the Future of Industry and Manufacturing',
#   'names': ['Miao Chun Yan',
#    'Douglas Leslie Maskell',
#    'Deepu Rajan',
#    'Ong Yew Soon',
#    'Wee Keong NG',
#    'Sun Aixin',
#    'Lu Shijian',
#    'Pan, Sinno Jialin',
#    'Luo Siqiang',
#    'Smitha K G',
#    'Joty Shafiq Rayhan',
#    'Siyuan Liu',
#    'Tan Rui',
#    'Zhang Tianwei',
#    'Vidya Sudarshan']},
#  {'keyword': 'Frailty: Use of AI-R Tool for Rehabilitation at Home Reducing the Need for Hospital Physiotherapy',
#   'names': ['Miao Chun Yan', 'Douglas Leslie Maskell', 'Deepu Rajan']},
#  {'keyword': 'Energy',
#   'names': ['Douglas Leslie Maskell', 'Zhao Jun', 'Tan Rui']},
#  {'keyword': 'Computational Intelligence',
#   'names': ['Chng Eng Siong',
#    'Jagath Chandana Rajapakse',
#    'Sun Aixin',
#    'Bo An',
#    'Erik Cambria',
#    'Guan Cuntai',
#    'Yu Han',
#    'Siyuan Liu',
#    'Wei Ying',
#    'Zhang Jie',
#    'Shen Zhiqi']},
#  {'keyword': 'Speech Recognition',
#   'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']},
#  {'keyword': 'Speech Enhancement',
#   'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']},
#  {'keyword': 'Speech Signal Processing',
#   'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']},
#  {'keyword': 'Speaker Speech Separation',
#   'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']},
#  {'keyword': 'Audio Processing',
#   'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']},
#  {'keyword': 'Speaker Diarization',
#   'names': ['Chng Eng Siong', 'Li Fang', 'Quek Hiok Chai']},
#  {'keyword': 'Financial Engineering & Risk Management',
#   'names': ['Quek Hiok Chai']},
#  {'keyword': 'Machines & Systems',
#   'names': ['Quek Hiok Chai',
#    'Goh Wooi Boon',
#    'Mohamed M. Sabry',
#    'Smitha K G',
#    'Loke Yuan Ren']},
#  {'keyword': 'Computer Vision and Sensing',
#   'names': ['Seah Hock Soon',
#    'Ong Chin Ann',
#    'Luo Jun',
#    'Lu Shijian',
#    'Shen Zhiqi']},
#  {'keyword': 'Graphics and Interactive Computing',
#   'names': ['Seah Hock Soon',
#    'Alexei Sourin',
#    'Yu Han',
#    'Owen Noel Newton Fernando',
#    'Lu Shijian',
#    'Shen Zhiqi']},
#  {'keyword': 'Animation', 'names': ['Seah Hock Soon']},
#  {'keyword': 'Interactive Media', 'names': ['Seah Hock Soon']},
#  {'keyword': 'Biomedical Engineering', 'names': ['Jagath Chandana Rajapakse']},
#  {'keyword': 'Information Sciences and Systems',
#   'names': ['Jagath Chandana Rajapakse',
#    'Sun Aixin',
#    'Bo An',
#    'Long Cheng',
#    'Erik Cambria',
#    'Yu Han']},
#  {'keyword': 'Healthy Brain Ageing', 'names': ['Jagath Chandana Rajapakse']},
#  {'keyword': 'Mental Health', 'names': ['Jagath Chandana Rajapakse']},
#  {'keyword': 'Neuroscience',
#   'names': ['Jagath Chandana Rajapakse', 'Lu Shijian']},
#  {'keyword': 'Biomedical Informatics and Data Science',
#   'names': ['Jagath Chandana Rajapakse', 'Guan Cuntai', 'Wei Ying']},
#  {'keyword': 'Computational and Systems Biology',
#   'names': ['Jagath Chandana Rajapakse',
#    'Zheng Jianmin',
#    'Chia Liang Tien',
#    'A S Madhukumar',
#    'Chan Syin',
#    'Hui Siu Cheung',
#    'Lam Siew Kei',
#    'Sourav Saha Bhowmick']},
#  {'keyword': 'Brain Image Analysis',
#   'names': ['Jagath Chandana Rajapakse',
#    'Zheng Jianmin',
#    'Chia Liang Tien',
#    'A S Madhukumar',
#    'Chan Syin',
#    'Hui Siu Cheung',
#    'Lam Siew Kei',
#    'Sourav Saha Bhowmick']},
#  {'keyword': 'Mechanical & Manufacturing Engineering',
#   'names': ['Zheng Jianmin', 'Qian Kemao']},
#  {'keyword': 'Art, Design and Media',
#   'names': ['Zheng Jianmin',
#    'Sourav Saha Bhowmick',
#    'Owen Noel Newton Fernando']},
#  {'keyword': 'Sociology', 'names': ['Sourav Saha Bhowmick', 'Cong Gao']},
#  {'keyword': 'EdTech & Science Communication',
#   'names': ['Alexei Sourin',
#    'Huang Shell Ying',
#    'Cham Tat Jen',
#    'Thambipillai Srikanthan',
#    'Goh Wooi Boon',
#    'Wentong Cai',
#    'Tang Xueyan']},
#  {'keyword': 'Urban Planning and Human Centered Design',
#   'names': ['Alexei Sourin',
#    'Huang Shell Ying',
#    'Cham Tat Jen',
#    'Thambipillai Srikanthan',
#    'Goh Wooi Boon',
#    'Wentong Cai',
#    'Tang Xueyan']},
#  {'keyword': 'Business and Management', 'names': ['Huang Shell Ying']},
#  {'keyword': 'Cyber Security and Forensics',
#   'names': ['Thambipillai Srikanthan',
#    'Wee Keong NG',
#    'Lam Kwok Yan',
#    'Lin Shang-Wei',
#    'Siyuan Liu',
#    'Liu Yang']},
#  {'keyword': 'Robotics and Intelligent Systems', 'names': ['Bo An']},
#  {'keyword': 'Economics', 'names': ['Bo An', 'Lu Shijian']},
#  {'keyword': 'Digital Economy',
#   'names': ['Bo An',
#    'Li Boyang',
#    'Lu Shijian',
#    'Pan, Sinno Jialin',
#    'Luo Siqiang',
#    'Smitha K G',
#    'Joty Shafiq Rayhan',
#    'Siyuan Liu',
#    'Tan Rui',
#    'Zhang Tianwei',
#    'Vidya Sudarshan']},
#  {'keyword': 'Technoethics', 'names': ['Bo An', 'Li Boyang']},
#  {'keyword': 'Internet of Things',
#   'names': ['Wei Yang Bryan Lim', 'Luo Jun', 'Li Mo', 'Siyuan Liu']},
#  {'keyword': 'Edge Intelligence', 'names': ['Wei Yang Bryan Lim']},
#  {'keyword': 'Data Management',
#   'names': ['Long Cheng',
#    'Cong Gao',
#    'Lin Guosheng',
#    'Yu Han',
#    'Zhang Hanwang',
#    'Oh Hong Lye',
#    'Josephine Chong',
#    'Luo Jun',
#    'Zhao Jun',
#    'Tay Kian Boon']},
#  {'keyword': 'Data Mining',
#   'names': ['Long Cheng',
#    'Cong Gao',
#    'Lin Guosheng',
#    'Yu Han',
#    'Zhang Hanwang',
#    'Oh Hong Lye',
#    'Josephine Chong',
#    'Luo Jun',
#    'Zhao Jun',
#    'Tay Kian Boon']},
#  {'keyword': 'Machine-Person Interoperability',
#   'names': ['Erik Cambria', 'Loke Yuan Ren']},
#  {'keyword': 'Affective Computing',
#   'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']},
#  {'keyword': 'Sentiment Analysis',
#   'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']},
#  {'keyword': 'Commonsense Reasoning',
#   'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']},
#  {'keyword': 'Neurosymbolic AI',
#   'names': ['Erik Cambria', 'Chen Change Loy', 'Chee Wei Tan']},
#  {'keyword': 'Brain Machine Interface',
#   'names': ['Guan Cuntai', 'Smitha K G']},
#  {'keyword': 'Machine Learning',
#   'names': ['Guan Cuntai',
#    'Wei Ying',
#    'Ke Yiping, Kelly',
#    'Loke Yuan Ren',
#    'Zhang Jie',
#    'Zinovi Rabinovich',
#    'Liu Ziwei']},
#  {'keyword': 'Neural Signal Processing', 'names': ['Guan Cuntai']},
#  {'keyword': 'Medical Image Analysis', 'names': ['Guan Cuntai']},
#  {'keyword': 'Cloud Computing',
#   'names': ['Dmitrii Ustiugov', 'Dusit Niyato', 'Lee Bu Sung']},
#  {'keyword': 'Distributed Operating Systems',
#   'names': ['Dmitrii Ustiugov', 'Dusit Niyato', 'Lee Bu Sung']},
#  {'keyword': 'Serverless Computing',
#   'names': ['Dmitrii Ustiugov', 'Dusit Niyato', 'Lee Bu Sung']},
#  {'keyword': 'Social Physics',
#   'names': ['Cong Gao',
#    'Lin Guosheng',
#    'Yu Han',
#    'Zhang Hanwang',
#    'Oh Hong Lye',
#    'Josephine Chong',
#    'Luo Jun',
#    'Zhao Jun',
#    'Tay Kian Boon']},
#  {'keyword': 'Data Science',
#   'names': ['Cong Gao',
#    'Lin Guosheng',
#    'Yu Han',
#    'Zhang Hanwang',
#    'Oh Hong Lye',
#    'Josephine Chong',
#    'Luo Jun',
#    'Zhao Jun',
#    'Tay Kian Boon']},
#  {'keyword': 'Language & Communication', 'names': ['Zhang Hanwang']},
#  {'keyword': 'Science, Technology and Society', 'names': ['Zhao Jun']},
#  {'keyword': 'Responsible Banking and Investment',
#   'names': ['Lam Kwok Yan', 'Li Mo', 'Liu Weichen']},
#  {'keyword': 'Bayesian Statistical Probabilistic Programming',
#   'names': ['Luke Ong （翁之昊）',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Owen Noel Newton Fernando',
#    'Lin Shang-Wei']},
#  {'keyword': 'Programming Languages',
#   'names': ['Luke Ong （翁之昊）',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Owen Noel Newton Fernando',
#    'Lin Shang-Wei']},
#  {'keyword': 'Semantics of Computation',
#   'names': ['Luke Ong （翁之昊）',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Owen Noel Newton Fernando',
#    'Lin Shang-Wei']},
#  {'keyword': 'Verification and Formal Methods',
#   'names': ['Luke Ong （翁之昊）',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Owen Noel Newton Fernando',
#    'Lin Shang-Wei']},
#  {'keyword': 'Logic and Algorithms',
#   'names': ['Luke Ong （翁之昊）',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Owen Noel Newton Fernando',
#    'Lin Shang-Wei']},
#  {'keyword': 'Security',
#   'names': ['Luke Ong （翁之昊）',
#    'Qian Kemao',
#    'Mohamed M. Sabry',
#    'Owen Noel Newton Fernando',
#    'Lin Shang-Wei']},
#  {'keyword': 'Physics', 'names': ['Qian Kemao']},
#  {'keyword': 'Image and Video Analytics',
#   'names': ['Lu Shijian',
#    'Pan, Sinno Jialin',
#    'Luo Siqiang',
#    'Smitha K G',
#    'Joty Shafiq Rayhan',
#    'Siyuan Liu',
#    'Tan Rui',
#    'Zhang Tianwei',
#    'Vidya Sudarshan']},
#  {'keyword': 'Neurotechnology',
#   'names': ['Lu Shijian',
#    'Pan, Sinno Jialin',
#    'Luo Siqiang',
#    'Smitha K G',
#    'Joty Shafiq Rayhan',
#    'Siyuan Liu',
#    'Tan Rui',
#    'Zhang Tianwei',
#    'Vidya Sudarshan']},
#  {'keyword': 'Linguistics and Multilingual Studies',
#   'names': ['Joty Shafiq Rayhan']},
#  {'keyword': 'Ageing', 'names': ['Siyuan Liu', 'Shen Zhiqi']},
#  {'keyword': 'Artificial Intelligence for Drug Discovery',
#   'names': ['Wei Ying', 'Ke Yiping, Kelly', 'Loke Yuan Ren']},
#  {'keyword': 'Artificial Intelligence',
#   'names': ['Zhang Jie', 'Zinovi Rabinovich', 'Liu Ziwei', 'Shen Zhiqi']},
#  {'keyword': 'User Modeling',
#   'names': ['Zhang Jie', 'Zinovi Rabinovich', 'Liu Ziwei']},
#  {'keyword': 'Trust and Preference',
#   'names': ['Zhang Jie', 'Zinovi Rabinovich', 'Liu Ziwei']},
#  {'keyword': 'Software Agent Technology', 'names': ['Shen Zhiqi']}]

# %%
list_of_keywords = []
for dic in list_of_keywords_with_names:
    list_of_keywords.append(dic['keyword'])
list_of_keywords
# Out:
# ['Computer Science and Engineering',
#  'Smart Cities',
#  'Disruptive Technology and Materials',
#  'Medical Technology',
#  'Smart Nation',
#  'Electrical and Electronic Engineering',
#  'Microelectronics & Applications',
#  'Nanotechnology & Nano-Science',
#  'Security Studies & Policy Issues',
#  'Computing Hardware and Architecture',
#  'Hardware and Embedded Systems',
#  'Quantum Technology',
#  'Parallel and Distributed Computing',
#  'Info-Communication Technology',
#  'Internet & Communications',
#  'Biomedical Sciences & Life Sciences',
#  'Interface of Biology & Engineering (Engineering in Biology)',
#  'Mathematics',
#  'Systems and Engineering Management',
#  'Interactive Digital Media',
#  'Computer Networks and Communications',
#  'Artificial and Augmented Intelligence',
#  'Disrupting the Future of Industry and Manufacturing',
#  'Frailty: Use of AI-R Tool for Rehabilitation at Home Reducing the Need for Hospital Physiotherapy',
#  'Energy',
#  'Computational Intelligence',
#  'Speech Recognition',
#  'Speech Enhancement',
#  'Speech Signal Processing',
#  'Speaker Speech Separation',
#  'Audio Processing',
#  'Speaker Diarization',
#  'Financial Engineering & Risk Management',
#  'Machines & Systems',
#  'Computer Vision and Sensing',
#  'Graphics and Interactive Computing',
#  'Animation',
#  'Interactive Media',
#  'Biomedical Engineering',
#  'Information Sciences and Systems',
#  'Healthy Brain Ageing',
#  'Mental Health',
#  'Neuroscience',
#  'Biomedical Informatics and Data Science',
#  'Computational and Systems Biology',
#  'Brain Image Analysis',
#  'Mechanical & Manufacturing Engineering',
#  'Art, Design and Media',
#  'Sociology',
#  'EdTech & Science Communication',
#  'Urban Planning and Human Centered Design',
#  'Business and Management',
#  'Cyber Security and Forensics',
#  'Robotics and Intelligent Systems',
#  'Economics',
#  'Digital Economy',
#  'Technoethics',
#  'Internet of Things',
#  'Edge Intelligence',
#  'Data Management',
#  'Data Mining',
#  'Machine-Person Interoperability',
#  'Affective Computing',
#  'Sentiment Analysis',
#  'Commonsense Reasoning',
#  'Neurosymbolic AI',
#  'Brain Machine Interface',
#  'Machine Learning',
#  'Neural Signal Processing',
#  'Medical Image Analysis',
#  'Cloud Computing',
#  'Distributed Operating Systems',
#  'Serverless Computing',
#  'Social Physics',
#  'Data Science',
#  'Language & Communication',
#  'Science, Technology and Society',
#  'Responsible Banking and Investment',
#  'Bayesian Statistical Probabilistic Programming',
#  'Programming Languages',
#  'Semantics of Computation',
#  'Verification and Formal Methods',
#  'Logic and Algorithms',
#  'Security',
#  'Physics',
#  'Image and Video Analytics',
#  'Neurotechnology',
#  'Linguistics and Multilingual Studies',
#  'Ageing',
#  'Artificial Intelligence for Drug Discovery',
#  'Artificial Intelligence',
#  'User Modeling',
#  'Trust and Preference',
#  'Software Agent Technology']

# %%
############### FIND list of keywords
conn_str = "mongodb+srv://jingfang61:324UnxOg84pVLj9E@cluster0.h2vp8rc.mongodb.net/"
client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000)
db = client['scsedash'] 
collection = db['keywordsAndNames']
result = collection.distinct('keyword')

# Print or process the results
result
# Out:
# ['Affective Computing',
#  'Ageing',
#  'Animation',
#  'Art, Design and Media',
#  'Artificial Intelligence',
#  'Artificial Intelligence for Drug Discovery',
#  'Artificial and Augmented Intelligence',
#  'Audio Processing',
#  'Bayesian Statistical Probabilistic Programming',
#  'Biomedical Engineering',
#  'Biomedical Informatics and Data Science',
#  'Biomedical Sciences & Life Sciences',
#  'Brain Image Analysis',
#  'Brain Machine Interface',
#  'Business and Management',
#  'Cloud Computing',
#  'Commonsense Reasoning',
#  'Computational Intelligence',
#  'Computational and Systems Biology',
#  'Computer Networks and Communications',
#  'Computer Science and Engineering',
#  'Computer Vision and Sensing',
#  'Computing Hardware and Architecture',
#  'Cyber Security and Forensics',
#  'Data Management',
#  'Data Mining',
#  'Data Science',
#  'Digital Economy',
#  'Disrupting the Future of Industry and Manufacturing',
#  'Disruptive Technology and Materials',
#  'Distributed Operating Systems',
#  'Economics',
#  'EdTech & Science Communication',
#  'Edge Intelligence',
#  'Electrical and Electronic Engineering',
#  'Energy',
#  'Financial Engineering & Risk Management',
#  'Frailty: Use of AI-R Tool for Rehabilitation at Home Reducing the Need for Hospital Physiotherapy',
#  'Graphics and Interactive Computing',
#  'Hardware and Embedded Systems',
#  'Healthy Brain Ageing',
#  'Image and Video Analytics',
#  'Info-Communication Technology',
#  'Information Sciences and Systems',
#  'Interactive Digital Media',
#  'Interactive Media',
#  'Interface of Biology & Engineering (Engineering in Biology)',
#  'Internet & Communications',
#  'Internet of Things',
#  'Language & Communication',
#  'Linguistics and Multilingual Studies',
#  'Logic and Algorithms',
#  'Machine Learning',
#  'Machine-Person Interoperability',
#  'Machines & Systems',
#  'Mathematics',
#  'Mechanical & Manufacturing Engineering',
#  'Medical Image Analysis',
#  'Medical Technology',
#  'Mental Health',
#  'Microelectronics & Applications',
#  'Nanotechnology & Nano-Science',
#  'Neural Signal Processing',
#  'Neuroscience',
#  'Neurosymbolic AI',
#  'Neurotechnology',
#  'Parallel and Distributed Computing',
#  'Physics',
#  'Programming Languages',
#  'Quantum Technology',
#  'Responsible Banking and Investment',
#  'Robotics and Intelligent Systems',
#  'Science, Technology and Society',
#  'Security',
#  'Security Studies & Policy Issues',
#  'Semantics of Computation',
#  'Sentiment Analysis',
#  'Serverless Computing',
#  'Smart Cities',
#  'Smart Nation',
#  'Social Physics',
#  'Sociology',
#  'Software Agent Technology',
#  'Speaker Diarization',
#  'Speaker Speech Separation',
#  'Speech Enhancement',
#  'Speech Recognition',
#  'Speech Signal Processing',
#  'Systems and Engineering Management',
#  'Technoethics',
#  'Trust and Preference',
#  'Urban Planning and Human Centered Design',
#  'User Modeling',
#  'Verification and Formal Methods']

# %%
import pymongo
################# FIND THE PROF BASED ON KEYWORDS ####################
conn_str = "mongodb+srv://jingfang61:5tiCsIsCr58RSBWL@cluster0.h2vp8rc.mongodb.net/"
client = pymongo.MongoClient(conn_str, serverSelectionTimeoutMS=5000)
keywords = ['Smart Cities', 'Mental Health']
db = client['scsedash'] 
cursor = db.keywordsAndNames.find({"keyword": {"$in": keywords}},{"_id":0,"names":1})

names = []
for dic in cursor:
    names.extend(dic["names"])
names
# Out:
# ['Wai Kin Adams Kong',
#  'Chng Eng Siong',
#  'Alexei Sourin',
#  'Ong Yew Soon',
#  'Bo An',
#  'Bo An',
#  'Wei Yang Bryan Lim',
#  'Cong Gao',
#  'Lam Kwok Yan',
#  'Lu Shijian',
#  'Jagath Chandana Rajapakse']

# %%
################### find number of contributions over the years given name 
name = "Sun Aixin"
cursor = db.DBLP_publications.find({"name":name},{"_id":0})
for dic in cursor:
    print(dic)
# Out:
# {'name': 'Sun Aixin', 'num_contributions': {'2023': {'Journal Articles': 5, 'Conference and Workshop Papers': 13, 'Informal and Other Publications': 16}, '2015': {'Journal Articles': 4, 'Editorship': 1, 'Conference and Workshop Papers': 5}, '2019': {'Journal Articles': 6, 'Conference and Workshop Papers': 10, 'Informal and Other Publications': 8}, '2009': {'Journal Articles': 2, 'Conference and Workshop Papers': 11}, '2014': {'Journal Articles': 1, 'Conference and Workshop Papers': 10}, '2006': {'Journal Articles': 2, 'Conference and Workshop Papers': 6}, '2018': {'Journal Articles': 10, 'Conference and Workshop Papers': 9, 'Informal and Other Publications': 4}, '2004': {'Journal Articles': 1, 'Conference and Workshop Papers': 1, 'Books and Theses': 1}, '2001': {'Conference and Workshop Papers': 1}, '2005': {'Journal Articles': 3, 'Conference and Workshop Papers': 4}, '2021': {'Journal Articles': 4, 'Conference and Workshop Papers': 7, 'Informal and Other Publications': 10}, '2003': {'Journal Articles': 1, 'Conference and Workshop Papers': 2}, '2017': {'Journal Articles': 4, 'Editorship': 2, 'Conference and Workshop Papers': 7, 'Informal and Other Publications': 4}, '2008': {'Editorship': 1, 'Conference and Workshop Papers': 11}, '2016': {'Journal Articles': 1, 'Conference and Workshop Papers': 7, 'Informal and Other Publications': 1}, '2010': {'Parts in Books or Collections': 1, 'Journal Articles': 1, 'Conference and Workshop Papers': 8}, '2011': {'Parts in Books or Collections': 1, 'Journal Articles': 5, 'Editorship': 1, 'Conference and Workshop Papers': 6}, '2007': {'Conference and Workshop Papers': 11}, '2022': {'Reference Works': 1, 'Journal Articles': 4, 'Conference and Workshop Papers': 12, 'Informal and Other Publications': 13}, '2020': {'Journal Articles': 3, 'Editorship': 1, 'Conference and Workshop Papers': 8, 'Informal and Other Publications': 9}, '2013': {'Journal Articles': 2, 'Conference and Workshop Papers': 9}, '2012': {'Journal Articles': 2, 'Conference and Workshop Papers': 8}, '2002': {'Conference and Workshop Papers': 2}}}

# %%
################### find coauthor
name = "Li Fang"
cursor = db.coauthors.find({"name":name},{"_id":0})
for dic in cursor:
    print(dic)
# Out:
# {'name': 'Li Fang', 'coauthors': [{'coauthor_name': 'Maylor K. H. Leung', 'times': 7}, {'coauthor_name': 'Xiaozhou Yu', 'times': 1}, {'coauthor_name': 'Namisha Khanna', 'times': 1}, {'coauthor_name': 'Purva Satija', 'times': 1}, {'coauthor_name': 'Shirley Z. W. Tan', 'times': 1}, {'coauthor_name': 'Chuan Liu', 'times': 1}, {'coauthor_name': 'Cheng Shao Chian', 'times': 1}]}

# %%
#################### find keywords for given prof name
name = 'Li Fang'
cursor = db.professors.find({"name":name},{"_id":0})
result = []
for dic in cursor:
    result.append(dic)
result[0]['keywords']
# Out:
# ['Internet & Communications',
#  'Computer Science and Engineering',
#  'Speech Recognition',
#  'Speech Enhancement',
#  'Speech Signal Processing',
#  'Speaker Speech Separation',
#  'Audio Processing',
#  'Speaker Diarization']

# %%
#################### find publications
name = "Bo An"
cursor = db.DBLP_publications.find({"name":name},{"_id":0,"num_contributions":0})
data = []
for dic in cursor:
    data.append(dic)
data
# Out:
# [{'name': 'Bo An',
#   'publications': {'2023': {'Journal Articles': [{'title': 'Classifying ambiguous identities in hidden-role Stochastic games with multi-agent reinforcement learning.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2023',
#       'conference_name': 'Auton. Agents Multi Agent Syst.',
#       'url': 'https://doi.org/10.1007/s10458-023-09620-x',
#       'coauthors': ['Shijie Han',
#        'Siyuan Li',
#        'Bo An 0001',
#        'Wei Zhao',
#        'Peng Liu']},
#      {'title': 'Effective Interpretable Policy Distillation via Critical Experience Point Identification.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2023',
#       'conference_name': 'IEEE Intell. Syst.',
#       'url': 'https://doi.org/10.1109/MIS.2023.3265868',
#       'coauthors': ['Xiao Liu',
#        'Shuyang Liu',
#        'Bo An 0001',
#        'Yang Gao 0001',
#        'Shangdong Yang',
#        'Wenbin Li 0006']},
#      {'title': 'Multi-agent dueling Q-learning with mean field and value decomposition.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2023',
#       'conference_name': 'Pattern Recognit.',
#       'url': 'https://doi.org/10.1016/j.patcog.2023.109436',
#       'coauthors': ['Shifei Ding',
#        'Wei Du',
#        'Ling Ding',
#        'Lili Guo',
#        'Jian Zhang 0019',
#        'Bo An 0001']},
#      {'title': 'Reinforcement Learning for Quantitative Trading.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2023',
#       'conference_name': 'ACM Trans. Intell. Syst. Technol.',
#       'url': 'https://doi.org/10.1145/3582560',
#       'coauthors': ['Shuo Sun', 'Rundong Wang', 'Bo An 0001']},
#      {'title': 'Multiple-Instance Learning From Unlabeled Bags With Pairwise Similarity.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2023',
#       'conference_name': 'IEEE Trans. Knowl. Data Eng.',
#       'url': 'https://doi.org/10.1109/TKDE.2022.3232141',
#       'coauthors': ['Lei Feng 0006',
#        'Senlin Shu',
#        'Yuzhou Cao',
#        'Lue Tao',
#        'Hongxin Wei',
#        'Tao Xiang',
#        'Bo An 0001',
#        'Gang Niu 0001']},
#      {'title': 'PRUDEX-Compass: Towards Systematic Evaluation of Reinforcement Learning in Financial Markets.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2023',
#       'conference_name': 'Trans. Mach. Learn. Res.',
#       'url': 'https://openreview.net/forum?id=JjbsIYOuNi',
#       'coauthors': ['Shuo Sun', 'Molei Qin', 'Xinrun Wang', 'Bo An 0001']}],
#     'Editorship': [{'title': 'Proceedings of the 2023 International Conference on Autonomous Agents and Multiagent Systems, AAMAS 2023, London, United Kingdom, 29 May 2023 - 2 June 2023',
#       'internal_type': 'proceedings',
#       'type': 'Editorship',
#       'year': '2023',
#       'conference_name': 'AAMAS',
#       'url': 'https://dl.acm.org/doi/proceedings/10.5555/3545946?tocHeading=heading1',
#       'coauthors': []}],
#     'Conference and Workshop Papers': [{'title': 'An Efficient Deep Reinforcement Learning Algorithm for Solving Imperfect Information Extensive-Form Games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v37i5.25722',
#       'coauthors': ['Linjian Meng',
#        'Zhenxing Ge',
#        'Pinzhuo Tian',
#        'Bo An 0001',
#        'Yang Gao 0001']},
#      {'title': 'Partial-Label Regression.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v37i6.25871',
#       'coauthors': ['Xin Cheng',
#        'Deng-Bao Wang',
#        'Lei Feng',
#        'Min-Ling Zhang',
#        'Bo An 0001']},
#      {'title': 'Solving Large-Scale Pursuit-Evasion Games Using Pre-trained Strategies.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v37i10.26369',
#       'coauthors': ['Shuxin Li',
#        'Xinrun Wang',
#        'Youzhi Zhang 0001',
#        'Wanqi Xue',
#        'Jakub Cerný',
#        'Bo An 0001']},
#      {'title': 'Consistent Complementary-Label Learning via Order-Preserving Losses.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AISTATS',
#       'url': 'https://proceedings.mlr.press/v206/liu23g.html',
#       'coauthors': ['Shuqi Liu',
#        'Yuzhou Cao',
#        'Qiaozhen Zhang',
#        'Lei Feng 0006',
#        'Bo An 0001']},
#      {'title': 'Structural Credit Assignment-Guided Coordinated MCTS: An Efficient and Scalable Method for Online Multiagent Planning.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AAMAS',
#       'url': 'https://dl.acm.org/doi/10.5555/3545946.3598682',
#       'coauthors': ['Qian Che',
#        'Wanyuan Wang',
#        'Fengchen Wang',
#        'Tianchi Qiao',
#        'Xiang Liu',
#        'Jiuchuan Jiang',
#        'Bo An 0001',
#        'Yichuan Jiang']},
#      {'title': 'Off-Beat Multi-Agent Reinforcement Learning.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AAMAS',
#       'url': 'https://dl.acm.org/doi/10.5555/3545946.3598955',
#       'coauthors': ['Wei Qiu 0001',
#        'Weixun Wang',
#        'Rundong Wang',
#        'Bo An 0001',
#        'Yujing Hu',
#        'Svetlana Obraztsova',
#        'Zinovi Rabinovich',
#        'Jianye Hao',
#        'Yingfeng Chen',
#        'Changjie Fan']},
#      {'title': 'A Learning Approach to Complex Contagion Influence Maximization.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AAMAS',
#       'url': 'https://dl.acm.org/doi/10.5555/3545946.3599022',
#       'coauthors': ['Haipeng Chen 0001',
#        'Bryan Wilder',
#        'Wei Qiu 0001',
#        'Bo An 0001',
#        'Eric Rice',
#        'Milind Tambe']},
#      {'title': 'Finding Optimal Nash Equilibria in Multiplayer Games via Correlation Plans.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'AAMAS',
#       'url': 'https://dl.acm.org/doi/10.5555/3545946.3599052',
#       'coauthors': ['Youzhi Zhang 0001', 'Bo An 0001', 'V. S. Subrahmanian']},
#      {'title': 'RPM: Generalizable Multi-Agent Policies for Multi-Agent Reinforcement Learning.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'ICLR',
#       'url': 'https://openreview.net/pdf?id=HnSceSzlfrY',
#       'coauthors': ['Wei Qiu 0001',
#        'Xiao Ma 0006',
#        'Bo An 0001',
#        'Svetlana Obraztsova',
#        'Shuicheng Yan',
#        'Zhongwen Xu']},
#      {'title': 'Population-size-Aware Policy Optimization for Mean-Field Games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'ICLR',
#       'url': 'https://openreview.net/pdf?id=fB4V-2QvCEm',
#       'coauthors': ['Pengdeng Li',
#        'Xinrun Wang',
#        'Shuxin Li',
#        'Hau Chan',
#        'Bo An 0001']},
#      {'title': 'ResAct: Reinforcing Long-term Engagement in Sequential Recommendation with Residual Actor.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'ICLR',
#       'url': 'https://openreview.net/pdf?id=HmPOzJQhbwg',
#       'coauthors': ['Wanqi Xue',
#        'Qingpeng Cai 0001',
#        'Ruohan Zhan',
#        'Dong Zheng',
#        'Peng Jiang 0002',
#        'Kun Gai',
#        'Bo An 0001']},
#      {'title': 'Weakly Supervised Regression with Interval Targets.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'ICML',
#       'url': 'https://proceedings.mlr.press/v202/cheng23a.html',
#       'coauthors': ['Xin Cheng',
#        'Yuzhou Cao',
#        'Ximing Li',
#        'Bo An 0001',
#        'Lei Feng 0006']},
#      {'title': 'Mitigating Memorization of Noisy Labels by Clipping the Model Prediction.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'ICML',
#       'url': 'https://proceedings.mlr.press/v202/wei23e.html',
#       'coauthors': ['Hongxin Wei',
#        'Huiping Zhuang',
#        'Renchunzi Xie',
#        'Lei Feng',
#        'Gang Niu 0001',
#        'Bo An 0001',
#        'Yixuan Li']},
#      {'title': 'Controlling Type Confounding in Ad Hoc Teamwork with Instance-wise Teammate Feedback Rectification.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'ICML',
#       'url': 'https://proceedings.mlr.press/v202/xing23a.html',
#       'coauthors': ['Dong Xing',
#        'Pengjie Gu',
#        'Qian Zheng',
#        'Xinrun Wang',
#        'Shanqi Liu',
#        'Longtao Zheng',
#        'Bo An 0001',
#        'Gang Pan 0001']},
#      {'title': 'Exploring Leximin Principle for Fair Core-Selecting Combinatorial Auctions: Payment Rule Design and Implementation.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'IJCAI',
#       'url': 'https://doi.org/10.24963/ijcai.2023/287',
#       'coauthors': ['Hao Cheng',
#        'Shufeng Kong',
#        'Yanchen Deng',
#        'Caihua Liu',
#        'Xiaohu Wu',
#        'Bo An 0001',
#        'Chongjun Wang']},
#      {'title': 'Complex Contagion Influence Maximization: A Reinforcement Learning Approach.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'IJCAI',
#       'url': 'https://doi.org/10.24963/ijcai.2023/614',
#       'coauthors': ['Haipeng Chen 0001',
#        'Bryan Wilder',
#        'Wei Qiu 0001',
#        'Bo An 0001',
#        'Eric Rice',
#        'Milind Tambe']},
#      {'title': 'Mastering Stock Markets with Efficient Mixture of Diversified Trading Experts.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'KDD',
#       'url': 'https://doi.org/10.1145/3580305.3599424',
#       'coauthors': ['Shuo Sun',
#        'Xinrun Wang',
#        'Wanqi Xue',
#        'Xiaoxuan Lou',
#        'Bo An 0001']},
#      {'title': 'PrefRec: Recommender Systems with Human Preferences for Reinforcing Long-term User Engagement.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2023',
#       'conference_name': 'KDD',
#       'url': 'https://doi.org/10.1145/3580305.3599473',
#       'coauthors': ['Wanqi Xue',
#        'Qingpeng Cai 0001',
#        'Zhenghai Xue',
#        'Shuo Sun',
#        'Shuchang Liu 0006',
#        'Dong Zheng',
#        'Peng Jiang 0002',
#        'Kun Gai',
#        'Bo An 0001']}],
#     'Informal and Other Publications': [{'title': 'Reinforcement Learning from Diverse Human Preferences.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2301.11774',
#       'coauthors': ['Wanqi Xue',
#        'Bo An 0001',
#        'Shuicheng Yan',
#        'Zhongwen Xu']},
#      {'title': 'PRUDEX-Compass: Towards Systematic Evaluation of Reinforcement Learning in Financial Markets.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2302.00586',
#       'coauthors': ['Shuo Sun', 'Molei Qin', 'Xinrun Wang', 'Bo An 0001']},
#      {'title': 'Population-size-Aware Policy Optimization for Mean-Field Games.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2302.03364',
#       'coauthors': ['Pengdeng Li',
#        'Xinrun Wang',
#        'Shuxin Li',
#        'Hau Chan',
#        'Bo An 0001']},
#      {'title': 'Towards Skilled Population Curriculum for Multi-Agent Reinforcement Learning.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2302.03429',
#       'coauthors': ['Rundong Wang',
#        'Longtao Zheng',
#        'Wei Qiu 0001',
#        'Bowei He',
#        'Bo An 0001',
#        'Zinovi Rabinovich',
#        'Yujing Hu',
#        'Yingfeng Chen',
#        'Tangjie Lv',
#        'Changjie Fan']},
#      {'title': 'On the Importance of Feature Separability in Predicting Out-Of-Distribution Error.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2303.15488',
#       'coauthors': ['Renchunzi Xie',
#        'Hongxin Wei',
#        'Yuzhou Cao',
#        'Lei Feng 0006',
#        'Bo An 0001']},
#      {'title': 'State Regularized Policy Optimization on Data with Dynamics Shift.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2306.03552',
#       'coauthors': ['Zhenghai Xue',
#        'Qingpeng Cai 0001',
#        'Shuchang Liu 0006',
#        'Dong Zheng',
#        'Peng Jiang 0002',
#        'Kun Gai',
#        'Bo An 0001']},
#      {'title': 'Synapse: Leveraging Few-Shot Exemplars for Human-Level Computer Control.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2306.07863',
#       'coauthors': ['Longtao Zheng', 'Rundong Wang', 'Bo An 0001']},
#      {'title': 'Partial-Label Regression.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2306.08968',
#       'coauthors': ['Xin Cheng',
#        'Deng-Bao Wang',
#        'Lei Feng 0006',
#        'Min-Ling Zhang',
#        'Bo An 0001']},
#      {'title': 'Weakly Supervised Regression with Interval Targets.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2306.10458',
#       'coauthors': ['Xin Cheng',
#        'Yuzhou Cao',
#        'Ximing Li',
#        'Bo An 0001',
#        'Lei Feng 0006']},
#      {'title': 'Controlling Type Confounding in Ad Hoc Teamwork with Instance-wise Teammate Feedback Rectification.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2306.10944',
#       'coauthors': ['Dong Xing',
#        'Pengjie Gu',
#        'Qian Zheng',
#        'Xinrun Wang',
#        'Shanqi Liu',
#        'Longtao Zheng',
#        'Bo An 0001',
#        'Gang Pan 0001']},
#      {'title': 'IMM: An Imitative Reinforcement Learning Approach with Predictive Representation Learning for Automatic Market Making.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2308.08918',
#       'coauthors': ['Hui Niu',
#        'Siyuan Li',
#        'Jiahao Zheng',
#        'Zhouchi Lin',
#        'Jian Li',
#        'Jian Guo',
#        'Bo An 0001']},
#      {'title': 'Efficient Last-iterate Convergence Algorithms in Solving Games.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2308.11256',
#       'coauthors': ['Linjian Meng',
#        'Zhenxing Ge',
#        'Wenbin Li',
#        'Bo An 0001',
#        'Yang Gao 0001']},
#      {'title': 'Market-GAN: Adding Control to Financial Market Data Generation with Semantic Context.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2309.07708',
#       'coauthors': ['Haochong Xia', 'Shuo Sun', 'Xinrun Wang', 'Bo An 0001']},
#      {'title': 'AdaRec: Adaptive Sequential Recommendation for Reinforcing Long-term User Engagement.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2023',
#       'conference_name': 'CoRR',
#       'url': 'https://doi.org/10.48550/arXiv.2310.03984',
#       'coauthors': ['Zhenghai Xue',
#        'Qingpeng Cai 0001',
#        'Tianyou Zuo',
#        'Bin Yang',
#        'Lantao Hu',
#        'Peng Jiang 0002',
#        'Kun Gai',
#        'Bo An 0001']}]},
#    '2015': {'Journal Articles': [{'title': 'Multiagent Reinforcement Learning With Unshared Value Functions.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2015',
#       'conference_name': 'IEEE Trans. Cybern.',
#       'url': 'https://doi.org/10.1109/TCYB.2014.2332042',
#       'coauthors': ['Yujing Hu', 'Yang Gao 0001', 'Bo An 0001']},
#      {'title': 'Accelerating Multiagent Reinforcement Learning by Equilibrium Transfer.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2015',
#       'conference_name': 'IEEE Trans. Cybern.',
#       'url': 'https://doi.org/10.1109/TCYB.2014.2349152',
#       'coauthors': ['Yujing Hu', 'Yang Gao 0001', 'Bo An 0001']}],
#     'Editorship': [{'title': 'Agents and Data Mining Interaction - 10th International Workshop, ADMI 2014, Paris, France, May 5-9, 2014, Revised Selected Papers',
#       'internal_type': 'proceedings',
#       'type': 'Editorship',
#       'year': '2015',
#       'conference_name': 'ADMI',
#       'url': 'https://doi.org/10.1007/978-3-319-20230-3',
#       'coauthors': []}],
#     'Conference and Workshop Papers': [{'title': 'Game Theoretic Considerations for Optimizing Efficiency of Taxi Systems.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'AAAI Workshop: Computational Sustainability',
#       'url': 'http://aaai.org/ocs/index.php/WS/AAAIW15/paper/view/10070',
#       'coauthors': ['Jiarui Gan', 'Bo An 0001']},
#      {'title': 'Security Games with Protection Externalities.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v29i1.9323',
#       'coauthors': ['Jiarui Gan', 'Bo An 0001', 'Yevgeniy Vorobeychik']},
#      {'title': 'Optimizing Efficiency of Taxi Systems: Scaling-up and Handling Arbitrary Constraints.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2772946',
#       'coauthors': ['Jiarui Gan', 'Bo An 0001', 'Chunyan Miao']},
#      {'title': 'Learning in Multi-agent Systems with Sparse Interactions by Knowledge Transfer and Game Abstraction.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2773250',
#       'coauthors': ['Yujing Hu', 'Yang Gao 0001', 'Bo An 0001']},
#      {'title': 'Computing Quantal Response Equilibrium for Sponsored Search Auctions.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2773445',
#       'coauthors': ['Jiang Rong', 'Tao Qin', 'Bo An 0001']},
#      {'title': "Modeling Learner's Emotions with PAD.",
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'ICALT',
#       'url': 'https://doi.org/10.1109/ICALT.2015.117',
#       'coauthors': ['Matthias Chan Yong Shun',
#        'Miao-Chun Yan',
#        'Bo An 0001',
#        'Cyril Leung']},
#      {'title': 'Learning Personality Modeling for Regulating Learning Feedback.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'ICALT',
#       'url': 'https://doi.org/10.1109/ICALT.2015.118',
#       'coauthors': ['Matthias Chan Yong Shun',
#        'Miao-Chun Yan',
#        'Zhiqi Shen 0001',
#        'Bo An 0001']},
#      {'title': 'Computing Optimal Mixed Strategies for Security Games with Dynamic Payoffs.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'IJCAI',
#       'url': 'http://ijcai.org/Abstract/15/102',
#       'coauthors': ['Yue Yin',
#        'Haifeng Xu',
#        'Jiarui Gan',
#        'Bo An 0001',
#        'Albert Xin Jiang']},
#      {'title': 'Optimal Electric Vehicle Charging Station Placement.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2015',
#       'conference_name': 'IJCAI',
#       'url': 'http://ijcai.org/Abstract/15/377',
#       'coauthors': ['Yanhai Xiong',
#        'Jiarui Gan',
#        'Bo An 0001',
#        'Chunyan Miao',
#        'Ana L. C. Bazzan']}]},
#    '2019': {'Journal Articles': [{'title': 'A branch and price algorithm for EOS constellation imaging and downloading integrated scheduling problem.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2019',
#       'conference_name': 'Comput. Oper. Res.',
#       'url': 'https://doi.org/10.1016/j.cor.2018.12.007',
#       'coauthors': ['Xiaoxuan Hu',
#        'Waiming Zhu',
#        'Bo An 0001',
#        'Peng Jin',
#        'Wei Xia']},
#      {'title': 'Protecting internet infrastructure against link flooding attacks: A techno-economic perspective.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2019',
#       'conference_name': 'Inf. Sci.',
#       'url': 'https://doi.org/10.1016/j.ins.2018.04.050',
#       'coauthors': ['Xiaobo Ma',
#        'Jianfeng Li',
#        'Yajuan Tang',
#        'Bo An 0001',
#        'Xiaohong Guan']},
#      {'title': 'Competitive Cloud Pricing for Long-Term Revenue Maximization.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2019',
#       'conference_name': 'J. Comput. Sci. Technol.',
#       'url': 'https://doi.org/10.1007/s11390-019-1933-9',
#       'coauthors': ['Jiang Rong', 'Tao Qin', 'Bo An 0001']},
#      {'title': 'Strategic Social Team Crowdsourcing: Forming a Team of Truthful Workers for Crowdsourcing in Social Networks.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2019',
#       'conference_name': 'IEEE Trans. Mob. Comput.',
#       'url': 'https://doi.org/10.1109/TMC.2018.2860978',
#       'coauthors': ['Wanyuan Wang',
#        'Zhanpeng He',
#        'Peng Shi',
#        'Weiwei Wu 0001',
#        'Yichuan Jiang',
#        'Bo An 0001',
#        'Zhifeng Hao',
#        'Bing Chen 0002']},
#      {'title': 'Batch Allocation for Tasks with Overlapping Skill Requirements in Crowdsourcing.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2019',
#       'conference_name': 'IEEE Trans. Parallel Distributed Syst.',
#       'url': 'https://doi.org/10.1109/TPDS.2019.2894146',
#       'coauthors': ['Jiuchuan Jiang',
#        'Bo An 0001',
#        'Yichuan Jiang',
#        'Peng Shi',
#        'Zhan Bu',
#        'Jie Cao 0001']}],
#     'Conference and Workshop Papers': [{'title': 'A Memetic Approach for Sequential Security Games on a Plane with Moving Targets.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v33i01.3301970',
#       'coauthors': ['Jan Karwowski',
#        'Jacek Mandziuk',
#        'Adam Zychowski',
#        'Filip Grajek',
#        'Bo An 0001']},
#      {'title': 'Optimal Interdiction of Urban Criminals with the Aid of Real-Time Information.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v33i01.33011262',
#       'coauthors': ['Youzhi Zhang 0001',
#        'Qingyu Guo',
#        'Bo An 0001',
#        'Long Tran-Thanh',
#        'Nicholas R. Jennings']},
#      {'title': 'On the Inducibility of Stackelberg Equilibrium for Security Games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v33i01.33012020',
#       'coauthors': ['Qingyu Guo',
#        'Jiarui Gan',
#        'Fei Fang',
#        'Long Tran-Thanh',
#        'Milind Tambe',
#        'Bo An 0001']},
#      {'title': 'Partial Label Learning with Self-Guided Retraining.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v33i01.33013542',
#       'coauthors': ['Lei Feng 0006', 'Bo An 0001']},
#      {'title': 'Collaboration Based Multi-Label Learning.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v33i01.33013550',
#       'coauthors': ['Lei Feng 0006', 'Bo An 0001', 'Shuo He']},
#      {'title': 'Competitive Bridge Bidding with Deep Neural Networks.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=3331669',
#       'coauthors': ['Jiang Rong', 'Tao Qin', 'Bo An 0001']},
#      {'title': 'Efficient City-Scale Patrolling Using Decomposition and Grafting.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=3332077',
#       'coauthors': ['Wanyuan Wang',
#        'Zichen Dong',
#        'Bo An 0001',
#        'Yichuan Jiang']},
#      {'title': 'Choosing Protection: User Investments in Security Measures for Cyber Risk Management.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'GameSec',
#       'url': 'https://doi.org/10.1007/978-3-030-32430-8_3',
#       'coauthors': ['Yoav Ben Yaakov',
#        'Xinrun Wang',
#        'Joachim Meyer 0002',
#        'Bo An 0001']},
#      {'title': 'When Players Affect Target Values: Modeling and Solving Dynamic Partially Observable Security Games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'GameSec',
#       'url': 'https://doi.org/10.1007/978-3-030-32430-8_32',
#       'coauthors': ['Xinrun Wang',
#        'Milind Tambe',
#        'Branislav Bosanský',
#        'Bo An 0001']},
#      {'title': 'InBEDE: Integrating Contextual Bandit with TD Learning for Joint Pricing and Dispatch of Ride-Hailing Platforms.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'ICDM',
#       'url': 'https://doi.org/10.1109/ICDM.2019.00016',
#       'coauthors': ['Haipeng Chen 0001',
#        'Yan Jiao',
#        'Zhiwei (Tony) Qin',
#        'Xiaocheng Tang',
#        'Hao Li',
#        'Bo An 0001',
#        'Hongtu Zhu',
#        'Jieping Ye']},
#      {'title': 'Partial Label Learning by Semantic Difference Maximization.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'IJCAI',
#       'url': 'https://doi.org/10.24963/ijcai.2019/318',
#       'coauthors': ['Lei Feng 0006', 'Bo An 0001']},
#      {'title': 'Dynamic Electronic Toll Collection via Multi-Agent Deep Reinforcement Learning with Edge-Based Graph Convolutional Networks.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'IJCAI',
#       'url': 'https://doi.org/10.24963/ijcai.2019/635',
#       'coauthors': ['Wei Qiu 0001', 'Haipeng Chen 0001', 'Bo An 0001']},
#      {'title': 'Who Should Pay the Cost: A Game-theoretic Model for Government Subsidized Investments to Improve National Cybersecurity.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'IJCAI',
#       'url': 'https://doi.org/10.24963/ijcai.2019/834',
#       'coauthors': ['Xinrun Wang', 'Bo An 0001', 'Hau Chan']},
#      {'title': 'Manipulating a Learning Defender and Ways to Counteract.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'NeurIPS',
#       'url': 'https://proceedings.neurips.cc/paper/2019/hash/c4819d06b0ca810d38506453cfaae9d8-Abstract.html',
#       'coauthors': ['Jiarui Gan',
#        'Qingyu Guo',
#        'Long Tran-Thanh',
#        'Bo An 0001',
#        'Michael J. Wooldridge']},
#      {'title': 'Social Cost Guarantees in Smart Route Guidance.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'PRICAI (2)',
#       'url': 'https://doi.org/10.1007/978-3-030-29911-8_37',
#       'coauthors': ['Paolo Serafino',
#        'Carmine Ventre',
#        'Long Tran-Thanh',
#        'Jie Zhang 0008',
#        'Bo An 0001',
#        'Nick R. Jennings']},
#      {'title': 'Securing the Deep Fraud Detector in Large-Scale E-Commerce Platform via Adversarial Machine Learning Approach.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2019',
#       'conference_name': 'WWW',
#       'url': 'https://doi.org/10.1145/3308558.3313533',
#       'coauthors': ['Qingyu Guo',
#        'Zhao Li 0007',
#        'Bo An 0001',
#        'Pengrui Hui',
#        'Jiaming Huang',
#        'Long Zhang',
#        'Mengchen Zhao']}],
#     'Informal and Other Publications': [{'title': 'Partial Label Learning with Self-Guided Retraining.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1902.03045',
#       'coauthors': ['Lei Feng 0006', 'Bo An 0001']},
#      {'title': 'Collaboration based Multi-Label Learning.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1902.03047',
#       'coauthors': ['Lei Feng 0006', 'Bo An 0001', 'Shuo He']},
#      {'title': 'Competitive Bridge Bidding with Deep Neural Networks.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1903.00900',
#       'coauthors': ['Jiang Rong', 'Tao Qin', 'Bo An 0001']},
#      {'title': 'Manipulating a Learning Defender and Ways to Counteract.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1905.11759',
#       'coauthors': ['Jiarui Gan',
#        'Qingyu Guo',
#        'Long Tran-Thanh',
#        'Bo An 0001',
#        'Michael J. Wooldridge']},
#      {'title': 'Social Cost Guarantees in Smart Route Guidance.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1906.06617',
#       'coauthors': ['Paolo Serafino',
#        'Carmine Ventre',
#        'Long Tran-Thanh',
#        'Jie Zhang 0008',
#        'Bo An 0001',
#        'Nick R. Jennings']},
#      {'title': 'Learning Efficient Multi-agent Communication: An Information Bottleneck Approach.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1911.06992',
#       'coauthors': ['Rundong Wang',
#        'Xu He',
#        'Runsheng Yu',
#        'Wei Qiu 0001',
#        'Bo An 0001',
#        'Zinovi Rabinovich']},
#      {'title': 'Inducing Cooperation via Team Regret Minimization based Multi-Agent Deep Reinforcement Learning.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1911.07712',
#       'coauthors': ['Runsheng Yu',
#        'Zhenyu Shi',
#        'Xinrun Wang',
#        'Rundong Wang',
#        'Buhong Liu',
#        'Xinwen Hou',
#        'Hanjiang Lai',
#        'Bo An 0001']},
#      {'title': 'Learning from Multiple Complementary Labels.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2019',
#       'conference_name': 'CoRR',
#       'url': 'http://arxiv.org/abs/1912.12927',
#       'coauthors': ['Lei Feng 0006', 'Bo An 0001']}]},
#    '2009': {'Journal Articles': [{'title': 'Evolving Best-Response Strategies for Market-Driven Agents Using Aggregative Fitness GA.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2009',
#       'conference_name': 'IEEE Trans. Syst. Man Cybern. Part C',
#       'url': 'https://doi.org/10.1109/TSMCC.2009.2014880',
#       'coauthors': ['Kwang Mong Sim', 'Bo An 0001']}],
#     'Conference and Workshop Papers': [{'title': 'Bilateral Bargaining with One-Sided Two-Type Uncertainty.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2009',
#       'conference_name': 'IAT',
#       'url': 'https://doi.org/10.1109/WI-IAT.2009.185',
#       'coauthors': ['Bo An 0001', 'Nicola Gatti 0001', 'Victor R. Lesser']},
#      {'title': 'Extending Alternating-Offers Bargaining in One-to-Many and Many-to-Many Settings.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2009',
#       'conference_name': 'IAT',
#       'url': 'https://doi.org/10.1109/WI-IAT.2009.188',
#       'coauthors': ['Bo An 0001', 'Nicola Gatti 0001', 'Victor R. Lesser']}]},
#    '2014': {'Journal Articles': [{'title': 'An extended study on multi-objective security games.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2014',
#       'conference_name': 'Auton. Agents Multi Agent Syst.',
#       'url': 'https://doi.org/10.1007/s10458-012-9209-6',
#       'coauthors': ['Matthew Brown 0002',
#        'Bo An 0001',
#        'Christopher Kiekintveld',
#        'Fernando Ordóñez',
#        'Milind Tambe']},
#      {'title': 'Filtering trust opinions through reinforcement learning.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2014',
#       'conference_name': 'Decis. Support Syst.',
#       'url': 'https://doi.org/10.1016/j.dss.2014.06.006',
#       'coauthors': ['Han Yu 0001',
#        'Zhiqi Shen 0001',
#        'Chunyan Miao',
#        'Bo An 0001',
#        'Cyril Leung']}],
#     'Conference and Workshop Papers': [{'title': 'Regret-Based Optimization and Preference Elicitation for Stackelberg Security Games with Uncertainty.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v28i1.8804',
#       'coauthors': ['Thanh Hong Nguyen',
#        'Amulya Yadav',
#        'Bo An 0001',
#        'Milind Tambe',
#        'Craig Boutilier']},
#      {'title': 'Game-Theoretic Resource Allocation for Protecting Large Public Events.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v28i1.8794',
#       'coauthors': ['Yue Yin', 'Bo An 0001', 'Manish Jain']},
#      {'title': 'Computing Solutions in Infinite-Horizon Discounted Adversarial Patrolling Games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'ICAPS',
#       'url': 'http://www.aaai.org/ocs/index.php/ICAPS/ICAPS14/paper/view/7783',
#       'coauthors': ['Yevgeniy Vorobeychik',
#        'Bo An 0001',
#        'Milind Tambe',
#        'Satinder Singh 0001']},
#      {'title': 'Reputation-aware task allocation for human trustees.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2615791',
#       'coauthors': ['Han Yu 0001',
#        'Chunyan Miao',
#        'Bo An 0001',
#        'Zhiqi Shen 0001',
#        'Cyril Leung']},
#      {'title': 'A practical robustness measure of incentive mechanisms.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2617482',
#       'coauthors': ['Yuan Liu 0002',
#        'Jie Zhang 0002',
#        'Bo An 0001',
#        'Sandip Sen']},
#      {'title': 'Modeling curiosity for virtual learning companions.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2617493',
#       'coauthors': ['Qiong Wu 0001', 'Chunyan Miao', 'Bo An 0001']},
#      {'title': 'An efficient algorithm for taxi system optimization.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2617525',
#       'coauthors': ['Jiarui Gan', 'Bo An 0001', 'Chunyan Miao']},
#      {'title': 'Dynamic allocation of security resources for protecting public events.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2617529',
#       'coauthors': ['Yue Yin', 'Bo An 0001', 'Manish Jain']},
#      {'title': 'Human-Computer Negotiation in Three-Player Market Settings.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'ECAI',
#       'url': 'https://doi.org/10.3233/978-1-61499-419-0-417',
#       'coauthors': ['Galit Haim',
#        "Ya'akov (Kobi) Gal",
#        'Sarit Kraus',
#        'Bo An 0001']},
#      {'title': 'A New Paradigm for the Study of Corruption in Different Cultures.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2014',
#       'conference_name': 'SBP',
#       'url': 'https://doi.org/10.1007/978-3-319-05579-4_32',
#       'coauthors': ["Ya'akov (Kobi) Gal",
#        'Avi Rosenfeld',
#        'Sarit Kraus',
#        'Michele Gelfand',
#        'Bo An 0001',
#        'Jun Lin']}]},
#    '2006': {'Journal Articles': [{'title': 'Fuzzy cognitive maps for dynamic grid service negotiation.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2006',
#       'conference_name': 'Multiagent Grid Syst.',
#       'url': 'https://doi.org/10.3233/mgs-2006-2202',
#       'coauthors': ['Chunyan Miao',
#        'Jianshu Weng',
#        'Angela Goh',
#        'Zhiqi Shen 0001',
#        'Bo An 0001']},
#      {'title': 'Continuous-Time Negotiation Mechanism for Software Agents.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2006',
#       'conference_name': 'IEEE Trans. Syst. Man Cybern. Part B',
#       'url': 'https://doi.org/10.1109/TSMCB.2006.874686',
#       'coauthors': ['Bo An 0001',
#        'Kwang Mong Sim',
#        'Liang Gui Tang',
#        'Shuang Qing Li',
#        'Dai Jie Cheng']}]},
#    '2018': {'Journal Articles': [{'title': 'Optimal defense against election control by deleting voter groups.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2018',
#       'conference_name': 'Artif. Intell.',
#       'url': 'https://doi.org/10.1016/j.artint.2018.02.001',
#       'coauthors': ['Yue Yin',
#        'Yevgeniy Vorobeychik',
#        'Bo An 0001',
#        'Noam Hazon']},
#      {'title': 'Predicting Human Decision-Making: From Prediction to Action, Ariel Rosenfeld, Sarit Kraus. Morgan & Claypool Publishers (2018).',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2018',
#       'conference_name': 'Artif. Intell.',
#       'url': 'https://doi.org/10.1016/j.artint.2018.07.003',
#       'coauthors': ['Bo An 0001']},
#      {'title': 'Camera Placement Based on Vehicle Traffic for Better City Security Surveillance.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2018',
#       'conference_name': 'IEEE Intell. Syst.',
#       'url': 'https://doi.org/10.1109/MIS.2018.223110904',
#       'coauthors': ['Xiaobo Ma',
#        'Yihui He',
#        'Xiapu Luo',
#        'Jianfeng Li',
#        'Mengchen Zhao',
#        'Bo An 0001',
#        'Xiaohong Guan']},
#      {'title': 'Active learning with confidence-based answers for crowdsourcing labeling tasks.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2018',
#       'conference_name': 'Knowl. Based Syst.',
#       'url': 'https://doi.org/10.1016/j.knosys.2018.07.010',
#       'coauthors': ['Jinhua Song',
#        'Hao Wang 0013',
#        'Yang Gao 0001',
#        'Bo An 0001']},
#      {'title': 'Understanding Crowdsourcing Systems from a Multiagent Perspective and Approach.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2018',
#       'conference_name': 'ACM Trans. Auton. Adapt. Syst.',
#       'url': 'https://doi.org/10.1145/3226028',
#       'coauthors': ['Jiuchuan Jiang',
#        'Bo An 0001',
#        'Yichuan Jiang',
#        'Donghui Lin',
#        'Zhan Bu',
#        'Jie Cao 0001',
#        'Zhifeng Hao']},
#      {'title': 'ACM TIST Special Issue on Urban Intelligence.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2018',
#       'conference_name': 'ACM Trans. Intell. Syst. Technol.',
#       'url': 'https://doi.org/10.1145/3154942',
#       'coauthors': ['Bo An 0001',
#        'Nicholas R. Jennings',
#        'Zhenhui Jessie Li']},
#      {'title': 'Optimal Electric Vehicle Fast Charging Station Placement Based on Game Theoretical Framework.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2018',
#       'conference_name': 'IEEE Trans. Intell. Transp. Syst.',
#       'url': 'https://doi.org/10.1109/TITS.2017.2754382',
#       'coauthors': ['Yanhai Xiong',
#        'Jiarui Gan',
#        'Bo An 0001',
#        'Chunyan Miao',
#        'Ana L. C. Bazzan']}],
#     'Editorship': [{'title': 'Advances in Practical Applications of Agents, Multi-Agent Systems, and Complexity: The PAAMS Collection - 16th International Conference, PAAMS 2018, Toledo, Spain, June 20-22, 2018, Proceedings',
#       'internal_type': 'proceedings',
#       'type': 'Editorship',
#       'year': '2018',
#       'conference_name': 'PAAMS',
#       'url': 'https://doi.org/10.1007/978-3-319-94580-4',
#       'coauthors': []}],
#     'Conference and Workshop Papers': [{'title': 'Catching Captain Jack: Efficient Time and Space Dependent Patrols to Combat Oil-Siphoning in International Waters.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v32i1.11291',
#       'coauthors': ['Xinrun Wang',
#        'Bo An 0001',
#        'Martin Strobel 0001',
#        'Fookwai Kong']},
#      {'title': 'DyETC: Dynamic Electronic Toll Collection for Traffic Congestion Alleviation.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v32i1.11337',
#       'coauthors': ['Haipeng Chen 0001',
#        'Bo An 0001',
#        'Guni Sharon',
#        'Josiah P. Hanna',
#        'Peter Stone',
#        'Chunyan Miao',
#        'Yeng Chai Soh']},
#      {'title': 'Optimal Spot-Checking for Improving Evaluation Accuracy of Peer Grading Systems.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v32i1.11336',
#       'coauthors': ['Wanyuan Wang', 'Bo An 0001', 'Yichuan Jiang']},
#      {'title': 'Data Poisoning Attacks on Multi-Task Relationship Learning.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v32i1.11838',
#       'coauthors': ['Mengchen Zhao',
#        'Bo An 0001',
#        'Yaodong Yu',
#        'Sulin Liu',
#        'Sinno Jialin Pan']},
#      {'title': 'Dynamic Pricing for Reusable Resources in Competitive Market With Stochastic Demand.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v32i1.11591',
#       'coauthors': ['Jiang Rong', 'Tao Qin', 'Bo An 0001']},
#      {'title': 'HogRider: Champion Agent of Microsoft Malmo Collaborative AI Challenge.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v32i1.11581',
#       'coauthors': ['Yanhai Xiong',
#        'Haipeng Chen 0001',
#        'Mengchen Zhao',
#        'Bo An 0001']},
#      {'title': 'Equilibrium Refinement in Security Games with Arbitrary Scheduling Constraints.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=3237836',
#       'coauthors': ['Kai Wang 0040',
#        'Qingyu Guo',
#        'Phebe Vayanos',
#        'Milind Tambe',
#        'Bo An 0001']},
#      {'title': 'Inducible Equilibrium for Security Games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=3238033',
#       'coauthors': ['Qingyu Guo',
#        'Jiarui Gan',
#        'Fei Fang',
#        'Long Tran-Thanh',
#        'Milind Tambe',
#        'Bo An 0001']},
#      {'title': 'Leveraging Latent Label Distributions for Partial Label Learning.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
#       'conference_name': 'IJCAI',
#       'url': 'https://doi.org/10.24963/ijcai.2018/291',
#       'coauthors': ['Lei Feng 0006', 'Bo An 0001']},
#      {'title': 'Impression Allocation for Combating Fraud in E-commerce Via Deep Reinforcement Learning with Action Norm Penalty.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2018',
# ...
#      {'title': 'Learning Behaviors with Uncertain Human Feedback.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2020',
#       'conference_name': 'UAI',
#       'url': 'http://proceedings.mlr.press/v124/he20a.html',
#       'coauthors': ['Xu He', 'Haipeng Chen 0001', 'Bo An 0001']}],
#     'Informal and Other Publications': [{'title': 'Combating noisy labels by agreement: A joint training method with co-regularization.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2003.02752',
#       'coauthors': ['Hongxin Wei',
#        'Lei Feng 0006',
#        'Xiangyu Chen',
#        'Bo An 0001']},
#      {'title': 'Learning Behaviors with Uncertain Human Feedback.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2006.04201',
#       'coauthors': ['Xu He', 'Haipeng Chen 0001', 'Bo An 0001']},
#      {'title': 'Provably Consistent Partial-Label Learning.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2007.08929',
#       'coauthors': ['Lei Feng 0006',
#        'Jiaqi Lv',
#        'Bo Han 0003',
#        'Miao Xu',
#        'Gang Niu 0001',
#        'Xin Geng',
#        'Bo An 0001',
#        'Masashi Sugiyama']},
#      {'title': 'Contextual User Browsing Bandits for Large-Scale Online Mobile Recommendation.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2008.09368',
#       'coauthors': ['Xu He',
#        'Bo An 0001',
#        'Yanghua Li',
#        'Haikai Chen',
#        'Qingyu Guo',
#        'Xin Li',
#        'Zhirong Wang']},
#      {'title': 'Learning to Collaborate in Multi-Module Recommendation via Multi-Agent Reinforcement Learning without Communication.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2008.09369',
#       'coauthors': ['Xu He',
#        'Bo An 0001',
#        'Yanghua Li',
#        'Haikai Chen',
#        'Rundong Wang',
#        'Xinrun Wang',
#        'Runsheng Yu',
#        'Xin Li',
#        'Zhirong Wang']},
#      {'title': 'Computing Ex Ante Coordinated Team-Maxmin Equilibria in Zero-Sum Multiplayer Extensive-Form Games.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2009.12629',
#       'coauthors': ['Youzhi Zhang 0001', 'Bo An 0001']},
#      {'title': 'Complexity and Algorithms for Exploiting Quantal Opponents in Large Two-Player Games.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2009.14521',
#       'coauthors': ['David Milec',
#        'Jakub Cerný',
#        'Viliam Lisý',
#        'Bo An 0001']},
#      {'title': 'Pointwise Binary Classification with Pairwise Confidence Comparisons.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2010.01875',
#       'coauthors': ['Lei Feng 0006',
#        'Senlin Shu',
#        'Nan Lu',
#        'Bo Han 0003',
#        'Miao Xu',
#        'Gang Niu 0001',
#        'Bo An 0001',
#        'Masashi Sugiyama']},
#      {'title': 'SemiNLL: A Framework of Noisy-Label Learning by Semi-Supervised Learning.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2012.00925',
#       'coauthors': ['Zhuowei Wang 0003',
#        'Jing Jiang 0002',
#        'Bo Han 0003',
#        'Lei Feng 0006',
#        'Bo An 0001',
#        'Gang Niu 0001',
#        'Guodong Long']},
#      {'title': 'Efficient Reservoir Management through Deep Reinforcement Learning.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2012.03822',
#       'coauthors': ['Xinrun Wang',
#        'Tarun Nair',
#        'Haoyang Li',
#        'Yuh Sheng Reuben Wong',
#        'Nachiket Kelkar',
#        'Srinivas Vaidyanathan',
#        'Rajat Nayak',
#        'Bo An 0001',
#        'Jagdish Krishnaswamy',
#        'Milind Tambe']},
#      {'title': 'MetaInfoNet: Learning Task-Guided Information for Sample Reweighting.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2012.05273',
#       'coauthors': ['Hongxin Wei',
#        'Lei Feng 0006',
#        'Rundong Wang',
#        'Bo An 0001']},
#      {'title': 'Personalized Adaptive Meta Learning for Cold-start User Preference Prediction.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2012.11842',
#       'coauthors': ['Runsheng Yu',
#        'Yu Gong',
#        'Xu He',
#        'Bo An 0001',
#        'Yu Zhu',
#        'Qingwen Liu',
#        'Wenwu Ou']},
#      {'title': 'Commission Fee is not Enough: A Hierarchical Reinforced Framework for Portfolio Management.',
#       'internal_type': 'article - informal',
#       'type': 'Informal and Other Publications',
#       'year': '2020',
#       'conference_name': 'CoRR',
#       'url': 'https://arxiv.org/abs/2012.12620',
#       'coauthors': ['Rundong Wang',
#        'Hongxin Wei',
#        'Bo An 0001',
#        'Zhouyan Feng',
#        'Jun Yao']}]},
#    '2013': {'Parts in Books or Collections': [{'title': 'Security Games Applied to Real-World: Research Contributions and Challenges.',
#       'internal_type': 'incollection',
#       'type': 'Parts in Books or Collections',
#       'year': '2013',
#       'conference_name': 'Moving Target Defense',
#       'url': 'https://doi.org/10.1007/978-1-4614-5416-8_2',
#       'coauthors': ['Manish Jain', 'Bo An 0001', 'Milind Tambe']}],
#     'Journal Articles': [{'title': 'Bilateral bargaining with one-sided uncertain reserve prices.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2013',
#       'conference_name': 'Auton. Agents Multi Agent Syst.',
#       'url': 'https://doi.org/10.1007/s10458-012-9198-5',
#       'coauthors': ['Bo An 0001', 'Nicola Gatti 0001', 'Victor R. Lesser']},
#      {'title': 'A Deployed Quantal Response-Based Patrol Planning System for the U.S. Coast Guard.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2013',
#       'conference_name': 'Interfaces',
#       'url': 'https://doi.org/10.1287/inte.2013.0700',
#       'coauthors': ['Bo An 0001',
#        'Fernando Ordóñez',
#        'Milind Tambe',
#        'Eric Shieh',
#        'Rong Yang',
#        'Craig Baldwin',
#        'Joseph DiRenzo',
#        'Kathryn Moretti',
#        'Ben Maule',
#        'Garrett Meyer']}],
#     'Conference and Workshop Papers': [{'title': 'Security games with surveillance cost and optimal timing of attack execution.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2013',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2484958',
#       'coauthors': ['Bo An 0001',
#        'Matthew Brown 0002',
#        'Yevgeniy Vorobeychik',
#        'Milind Tambe']},
#      {'title': 'A reputation-aware decision-making approach for improving the efficiency of crowdsourcing systems.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2013',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2485201',
#       'coauthors': ['Han Yu 0001',
#        'Zhiqi Shen 0001',
#        'Chunyan Miao',
#        'Bo An 0001']},
#      {'title': 'A Reputation Management Approach for Resource Constrained Trustee Agents.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2013',
#       'conference_name': 'IJCAI',
#       'url': 'http://www.aaai.org/ocs/index.php/IJCAI/IJCAI13/paper/view/6186',
#       'coauthors': ['Han Yu 0001',
#        'Chunyan Miao',
#        'Bo An 0001',
#        'Cyril Leung',
#        'Victor R. Lesser']},
#      {'title': 'Optimal Pricing for Improving Efficiency of Taxi Systems.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2013',
#       'conference_name': 'IJCAI',
#       'url': 'http://www.aaai.org/ocs/index.php/IJCAI/IJCAI13/paper/view/6540',
#       'coauthors': ['Jiarui Gan',
#        'Bo An 0001',
#        'Haizhong Wang',
#        'Xiaoming Sun',
#        'Zhongzhi Shi']}]},
#    '2012': {'Parts in Books or Collections': [{'title': 'Yushu: A Heuristic-Based Agent for Automated Negotiating Competition.',
#       'internal_type': 'incollection',
#       'type': 'Parts in Books or Collections',
#       'year': '2012',
#       'conference_name': 'New Trends in Agent-Based Complex Automated Negotiations',
#       'url': 'https://doi.org/10.1007/978-3-642-24696-8_9',
#       'coauthors': ['Bo An 0001', 'Victor R. Lesser']}],
#     'Journal Articles': [{'title': 'An Overview of Recent Application Trends at the AAMAS Conference: Security, Sustainability and Safety.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2012',
#       'conference_name': 'AI Mag.',
#       'url': 'https://doi.org/10.1609/aimag.v33i3.2420',
#       'coauthors': ['Manish Jain', 'Bo An 0001', 'Milind Tambe']},
#      {'title': 'Reports of the AAAI 2012 Spring Symposia.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2012',
#       'conference_name': 'AI Mag.',
#       'url': 'https://doi.org/10.1609/aimag.v33i3.2428',
#       'coauthors': ['Harith Alani',
#        'Bo An 0001',
#        'Manish Jain',
#        'Takashi Kido',
#        'George Dimitri Konidaris',
#        'William F. Lawless',
#        'David L. Martin 0001',
#        'Caroline Pantofaru',
#        'Donald A. Sofge',
#        'Keiki Takadama',
#        'Milind Tambe',
#        'Tomas Vitvar']},
#      {'title': 'PROTECT - A Deployed Game Theoretic System for Strategic Security Allocation for the United States Coast Guard.',
#       'internal_type': 'article',
#       'type': 'Journal Articles',
#       'year': '2012',
#       'conference_name': 'AI Mag.',
#       'url': 'https://doi.org/10.1609/aimag.v33i4.2401',
#       'coauthors': ['Bo An 0001',
#        'Eric Shieh',
#        'Milind Tambe',
#        'Rong Yang',
#        'Craig Baldwin',
#        'Joseph DiRenzo',
#        'Ben Maule',
#        'Garrett Meyer']}],
#     'Conference and Workshop Papers': [{'title': 'Security Games with Limited Surveillance.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v26i1.8236',
#       'coauthors': ['Bo An 0001',
#        'David Kempe 0001',
#        'Christopher Kiekintveld',
#        'Eric Shieh',
#        'Satinder Singh 0001',
#        'Milind Tambe',
#        'Yevgeniy Vorobeychik']},
#      {'title': 'PROTECT: An Application of Computational Game Theory for the Security of the Ports of the United States.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAAI',
#       'url': 'https://doi.org/10.1609/aaai.v26i1.8436',
#       'coauthors': ['Eric Anyung Shieh',
#        'Bo An 0001',
#        'Rong Yang',
#        'Milind Tambe',
#        'Craig Baldwin',
#        'Joseph DiRenzo',
#        'Ben Maule',
#        'Garrett Meyer']},
#      {'title': 'Security Games with Limited Surveillance: An Initial Report.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAAI Spring Symposium: Game Theory for Security, Sustainability, and Health',
#       'url': 'http://www.aaai.org/ocs/index.php/SSS/SSS12/paper/view/4262',
#       'coauthors': ['Bo An 0001',
#        'David Kempe 0001',
#        'Christopher Kiekintveld',
#        'Eric Anyung Shieh',
#        'Satinder Singh 0001',
#        'Milind Tambe',
#        'Yevgeniy Vorobeychik']},
#      {'title': 'Getting Started on a Real-World Challenge Problem in Computational Game Theory and Beyond.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAAI Spring Symposium: AI, The Fundamental Social Aggregation Challenge',
#       'url': 'http://www.aaai.org/ocs/index.php/SSS/SSS12/paper/view/4269',
#       'coauthors': ['Milind Tambe', 'Bo An 0001']},
#      {'title': 'Game Theory for Security: A Real-World Challenge Problem for Multiagent Systems and Beyond.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAAI Spring Symposium: Game Theory for Security, Sustainability, and Health',
#       'url': 'http://www.aaai.org/ocs/index.php/SSS/SSS12/paper/view/4260',
#       'coauthors': ['Milind Tambe', 'Bo An 0001']},
#      {'title': 'Adversarial Patrolling Games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAAI Spring Symposium: Game Theory for Security, Sustainability, and Health',
#       'url': 'http://www.aaai.org/ocs/index.php/SSS/SSS12/paper/view/4255',
#       'coauthors': ['Yevgeniy Vorobeychik', 'Bo An 0001', 'Milind Tambe']},
#      {'title': 'PROTECT: a deployed game theoretic system to protect the ports of the United States.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2343578',
#       'coauthors': ['Eric Shieh',
#        'Bo An 0001',
#        'Rong Yang',
#        'Milind Tambe',
#        'Craig Baldwin',
#        'Joseph DiRenzo',
#        'Ben Maule',
#        'Garrett Meyer']},
#      {'title': 'Multi-objective optimization for security games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2343820',
#       'coauthors': ['Matthew Brown 0002',
#        'Bo An 0001',
#        'Christopher Kiekintveld',
#        'Fernando Ordóñez',
#        'Milind Tambe']},
#      {'title': 'Adversarial patrolling games.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'AAMAS',
#       'url': 'http://dl.acm.org/citation.cfm?id=2343977',
#       'coauthors': ['Yevgeniy Vorobeychik', 'Bo An 0001', 'Milind Tambe']},
#      {'title': 'Challenges and Opportunities for Trust Management in Crowdsourcing.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'IAT',
#       'url': 'https://doi.org/10.1109/WI-IAT.2012.104',
#       'coauthors': ['Han Yu 0001',
#        'Zhiqi Shen 0001',
#        'Chunyan Miao',
#        'Bo An 0001']},
#      {'title': 'An Adaptive Witness Selection Method for Reputation-Based Trust Models.',
#       'internal_type': 'inproceedings',
#       'type': 'Conference and Workshop Papers',
#       'year': '2012',
#       'conference_name': 'PRIMA',
#       'url': 'https://doi.org/10.1007/978-3-642-32729-2_13',
#       'coauthors': ['Han Yu 0001', 'Zhiqi Shen 0001', 'Bo An 0001']}]}}}]

# %%
from utils import find_publications
find_publications("Anwitaman Datta")
# Out:
# {'name': 'Anwitaman Datta',
#  'publications': {'2023': {'Journal Articles': [{'title': 'On parsimony and clustering.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2023',
#      'conference_name': 'PeerJ Comput. Sci.',
#      'url': 'https://doi.org/10.7717/peerj-cs.1339',
#      'coauthors': ['Frédérique E. Oggier', 'Anwitaman Datta']}],
#    'Conference and Workshop Papers': [{'title': 'Misinformation Concierge: A Proof-of-Concept with Curated Twitter Dataset on COVID-19 Vaccination.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2023',
#      'conference_name': 'CIKM',
#      'url': 'https://doi.org/10.1145/3583780.3614746',
#      'coauthors': ['Shakshi Sharma',
#       'Anwitaman Datta',
#       'Vigneshwaran Shankaran',
#       'Rajesh Sharma']}],
#    'Informal and Other Publications': [{'title': 'PIEChain - A Practical Blockchain Interoperability Framework.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2023',
#      'conference_name': 'CoRR',
#      'url': 'https://doi.org/10.48550/arXiv.2306.09735',
#      'coauthors': ['Daniël Reijsbergen',
#       'Aung Maw',
#       'Jingchi Zhang',
#       'Tien Tuan Anh Dinh',
#       'Anwitaman Datta']},
#     {'title': 'CroCoDai: A Stablecoin for Cross-Chain Commerce.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2023',
#      'conference_name': 'CoRR',
#      'url': 'https://doi.org/10.48550/arXiv.2306.09754',
#      'coauthors': ['Daniël Reijsbergen',
#       'Bretislav Hajek',
#       'Tien Tuan Anh Dinh',
#       'Jussi Keppo',
#       'Hank Korth',
#       'Anwitaman Datta']},
#     {'title': 'GovernR: Provenance and Confidentiality Guarantees In Research Data Repositories.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2023',
#      'conference_name': 'CoRR',
#      'url': 'https://doi.org/10.48550/arXiv.2307.14041',
#      'coauthors': ['Anwitaman Datta', 'Chua Chiah Soon', 'Wangfan Gu']},
#     {'title': 'BlockChain I/O: Enabling Cross-Chain Commerce.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2023',
#      'conference_name': 'CoRR',
#      'url': 'https://doi.org/10.48550/arXiv.2308.02163',
#      'coauthors': ['Anwitaman Datta',
#       'Daniël Reijsbergen',
#       'Jingchi Zhang',
#       'Suman Majumder']},
#     {'title': 'Misinformation Concierge: A Proof-of-Concept with Curated Twitter Dataset on COVID-19 Vaccination.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2023',
#      'conference_name': 'CoRR',
#      'url': 'https://doi.org/10.48550/arXiv.2309.00639',
#      'coauthors': ['Shakshi Sharma',
#       'Anwitaman Datta',
#       'Vigneshwaran Shankaran',
#       'Rajesh Sharma']},
#     {'title': 'Blockchain-enabled Data Governance for Privacy-Preserved Sharing of Confidential Data.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2023',
#      'conference_name': 'CoRR',
#      'url': 'https://doi.org/10.48550/arXiv.2309.04125',
#      'coauthors': ['Jingchi Zhang', 'Anwitaman Datta']}]},
#   '2015': {'Journal Articles': [{'title': 'Edge-centric Computing: Vision and Challenges.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2015',
#      'conference_name': 'Comput. Commun. Rev.',
#      'url': 'https://doi.org/10.1145/2831347.2831354',
#      'coauthors': ['Pedro García López',
#       'Alberto Montresor',
#       'Dick H. J. Epema',
#       'Anwitaman Datta',
#       'Teruo Higashino',
#       'Adriana Iamnitchi',
#       'Marinho P. Barcellos',
#       'Pascal Felber',
#       'Etienne Rivière']},
#     {'title': 'Self-repairing codes - Local repairability for cheap and fast maintenance of erasure coded data.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2015',
#      'conference_name': 'Computing',
#      'url': 'https://doi.org/10.1007/s00607-014-0426-5',
#      'coauthors': ['Frédérique E. Oggier', 'Anwitaman Datta']},
#     {'title': 'On repairing erasure coded data in an active-passive mixed storage network.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2015',
#      'conference_name': 'Int. J. Inf. Coding Theory',
#      'url': 'https://doi.org/10.1504/IJICOT.2015.068697',
#      'coauthors': ['Frédérique E. Oggier', 'Anwitaman Datta']},
#     {'title': 'Game-Theoretic Mechanisms to Increase Data Availability in Decentralized Storage Systems.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2015',
#      'conference_name': 'ACM Trans. Auton. Adapt. Syst.',
#      'url': 'https://doi.org/10.1145/2723771',
#      'coauthors': ['Krzysztof Rzadca',
#       'Anwitaman Datta',
#       'Gunnar Kreitz',
#       'Sonja Buchegger']},
#     {'title': 'BPMiner: Algorithms for Large-Scale Private Analysis.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2015',
#      'conference_name': 'Trans. Large Scale Data Knowl. Centered Syst.',
#      'url': 'https://doi.org/10.1007/978-3-662-48567-5_1',
#      'coauthors': ['Quach Vinh Thanh', 'Anwitaman Datta']}],
#    'Conference and Workshop Papers': [{'title': 'Sparsity Exploiting Erasure Coding for Resilient Storage and Efficient I/O Access in Delta Based Versioning Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2015',
#      'conference_name': 'ICDCS',
#      'url': 'https://doi.org/10.1109/ICDCS.2015.115',
#      'coauthors': ['J. Harshan', 'Frédérique E. Oggier', 'Anwitaman Datta']}],
#    'Informal and Other Publications': [{'title': 'Compressed Differential Erasure Codes for Efficient Archival of Versioned Data.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2015',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1503.05434',
#      'coauthors': ['J. Harshan', 'Anwitaman Datta', 'Frédérique E. Oggier']},
#     {'title': 'Auditable Versioned Data Storage Outsourcing.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2015',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1507.08838',
#      'coauthors': ['Ertem Esiner', 'Anwitaman Datta']}]},
#   '2019': {'Journal Articles': [{'title': 'Two-factor authentication for trusted third party free dispersed storage.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2019',
#      'conference_name': 'Future Gener. Comput. Syst.',
#      'url': 'https://doi.org/10.1016/j.future.2018.08.001',
#      'coauthors': ['Ertem Esiner', 'Anwitaman Datta']},
#     {'title': 'On hybrid network coding for visual traffic surveillance.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2019',
#      'conference_name': 'Future Gener. Comput. Syst.',
#      'url': 'https://doi.org/10.1016/j.future.2019.05.044',
#      'coauthors': ['Chih Wei Ling', 'Anwitaman Datta', 'Jun Xu']},
#     {'title': 'A split-and-transfer flow based entropic centrality.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2019',
#      'conference_name': 'PeerJ Comput. Sci.',
#      'url': 'https://doi.org/10.7717/peerj-cs.220',
#      'coauthors': ['Frédérique E. Oggier',
#       'Silivanxay Phetsouvanh',
#       'Anwitaman Datta']}],
#    'Conference and Workshop Papers': [{'title': 'Please, do not Decentralize the Internet with (Permissionless) Blockchains!',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2019',
#      'conference_name': 'ICDCS',
#      'url': 'https://doi.org/10.1109/ICDCS.2019.00188',
#      'coauthors': ['Pedro García López',
#       'Alberto Montresor',
#       'Anwitaman Datta']}],
#    'Informal and Other Publications': [{'title': 'Please, do not decentralize the Internet with (permissionless) blockchains!',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2019',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1904.13093',
#      'coauthors': ['Pedro García López',
#       'Alberto Montresor',
#       'Anwitaman Datta']},
#     {'title': 'Blockchain in the Government Technology Fabric.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2019',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1905.08517',
#      'coauthors': ['Anwitaman Datta']},
#     {'title': 'A Blueprint For Interoperable Blockchains.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2019',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1910.00985',
#      'coauthors': ['Tien Tuan Anh Dinh',
#       'Anwitaman Datta',
#       'Beng Chin Ooi']}]},
#   '2009': {'Reference Works': [{'title': 'Load Balancing in Peer-to-Peer Overlay Networks.',
#      'internal_type': 'incollection - encyclopedia',
#      'type': 'Reference Works',
#      'year': '2009',
#      'conference_name': 'Encyclopedia of Database Systems',
#      'url': 'https://doi.org/10.1007/978-0-387-39940-9_1043',
#      'coauthors': ['Anwitaman Datta']},
#     {'title': 'Peer-to-Peer Storage.',
#      'internal_type': 'incollection - encyclopedia',
#      'type': 'Reference Works',
#      'year': '2009',
#      'conference_name': 'Encyclopedia of Database Systems',
#      'url': 'https://doi.org/10.1007/978-0-387-39940-9_1216',
#      'coauthors': ['Anwitaman Datta']}],
#    'Journal Articles': [{'title': 'CMV: File consistency maintenance through virtual servers in peer-to-peer systems.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2009',
#      'conference_name': 'J. Parallel Distributed Comput.',
#      'url': 'https://doi.org/10.1016/j.jpdc.2009.01.005',
#      'coauthors': ['Zhijun Wang 0001',
#       'Anwitaman Datta',
#       'Sajal K. Das 0001',
#       'Mohan Kumar']}],
#    'Editorship': [{'title': 'Proceedings P2P 2009, Ninth International Conference on Peer-to-Peer Computing, 9-11 September 2009, Seattle, Washington, USA',
#      'internal_type': 'proceedings',
#      'type': 'Editorship',
#      'year': '2009',
#      'conference_name': 'Peer-to-Peer Computing',
#      'url': 'https://ieeexplore.ieee.org/xpl/conhome/5273785/proceeding',
#      'coauthors': []}],
#    'Conference and Workshop Papers': [{'title': 'SSnetViz: a visualization engine for heterogeneous semantic social networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'ICEC',
#      'url': 'https://doi.org/10.1145/1593254.1593288',
#      'coauthors': ['Ee-Peng Lim',
#       'Maureen',
#       'Nelman Lubis Ibrahim',
#       'Aixin Sun',
#       'Anwitaman Datta',
#       'Kuiyu Chang']},
#     {'title': 'Enabling Secure Secret Sharing in Distributed Online Social Networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'ACSAC',
#      'url': 'https://doi.org/10.1109/ACSAC.2009.46',
#      'coauthors': ['Le-Hung Vu',
#       'Karl Aberer',
#       'Sonja Buchegger',
#       'Anwitaman Datta']},
#     {'title': 'Multicast Trees for Collaborative Applications.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'CCGRID',
#      'url': 'https://doi.org/10.1109/CCGRID.2009.38',
#      'coauthors': ['Krzysztof Rzadca',
#       'Jackson Tan Teck Yong',
#       'Anwitaman Datta']},
#     {'title': 'Reliable P2P Feed Delivery.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'CCGRID',
#      'url': 'https://doi.org/10.1109/CCGRID.2009.32',
#      'coauthors': ['Anwitaman Datta', 'Xin Liu 0027']},
#     {'title': 'StereoTrust: a group based personalized trust model.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'CIKM',
#      'url': 'https://doi.org/10.1145/1645953.1645958',
#      'coauthors': ['Xin Liu 0027',
#       'Anwitaman Datta',
#       'Krzysztof Rzadca',
#       'Ee-Peng Lim']},
#     {'title': 'PeerSoN: P2P social networking: early experiences and insights.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'SNS',
#      'url': 'https://doi.org/10.1145/1578002.1578010',
#      'coauthors': ['Sonja Buchegger',
#       'Doris Schiöberg',
#       'Le-Hung Vu',
#       'Anwitaman Datta']},
#     {'title': 'Redundancy Maintenance and Garbage Collection Strategies in Peer-to-Peer Storage Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'SSS',
#      'url': 'https://doi.org/10.1007/978-3-642-05118-0_36',
#      'coauthors': ['Xin Liu 0027', 'Anwitaman Datta']},
#     {'title': 'On Stability, Clarity, and Co-occurrence of Self-Tagging.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2009',
#      'conference_name': 'WSDM (Late Breaking-Results)',
#      'url': '',
#      'coauthors': ['Aixin Sun', 'Anwitaman Datta']}]},
#   '2014': {'Reference Works': [{'title': 'Computational Trust Models.',
#      'internal_type': 'incollection - encyclopedia',
#      'type': 'Reference Works',
#      'year': '2014',
#      'conference_name': 'Encyclopedia of Social Network Analysis and Mining',
#      'url': 'https://doi.org/10.1007/978-1-4614-6170-8_228',
#      'coauthors': ['Xin Liu 0027', 'Anwitaman Datta', 'Karl Aberer']}],
#    'Journal Articles': [{'title': 'A Generic Trust Framework for Large-Scale Open Systems using Machine Learning.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2014',
#      'conference_name': 'Comput. Intell.',
#      'url': 'https://doi.org/10.1111/coin.12022',
#      'coauthors': ['Xin Liu 0027', 'Gilles Trédan', 'Anwitaman Datta']},
#     {'title': 'The zen of multidisciplinary team recommendation.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2014',
#      'conference_name': 'J. Assoc. Inf. Sci. Technol.',
#      'url': 'https://doi.org/10.1002/asi.23139',
#      'coauthors': ['Anwitaman Datta',
#       'Jackson Tan Teck Yong',
#       'Stefano Braghin']},
#     {'title': 'Mosco: a privacy-aware middleware for mobile social computing.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2014',
#      'conference_name': 'J. Syst. Softw.',
#      'url': 'https://doi.org/10.1016/j.jss.2013.11.1110',
#      'coauthors': ['Tien Tuan Anh Dinh',
#       'Milind Ganjoo',
#       'Stefano Braghin',
#       'Anwitaman Datta']},
#     {'title': 'Towards Kurdish Information Retrieval.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2014',
#      'conference_name': 'ACM Trans. Asian Lang. Inf. Process.',
#      'url': 'https://doi.org/10.1145/2556948',
#      'coauthors': ['Kyumars Sheykh Esmaili',
#       'Shahin Salavati',
#       'Anwitaman Datta']}],
#    'Conference and Workshop Papers': [{'title': 'People are processors: coalitional auctions for complex projects.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2014',
#      'conference_name': 'AAMAS',
#      'url': 'http://dl.acm.org/citation.cfm?id=2616044',
#      'coauthors': ['Piotr Skowron 0001',
#       'Krzysztof Rzadca',
#       'Anwitaman Datta']},
#     {'title': 'Streamforce: outsourcing access control enforcement for stream data to the clouds.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2014',
#      'conference_name': 'CODASPY',
#      'url': 'https://doi.org/10.1145/2557547.2557556',
#      'coauthors': ['Tien Tuan Anh Dinh', 'Anwitaman Datta']},
#     {'title': 'InterCloud RAIDer: A Do-It-Yourself Multi-cloud Private Data Backup System.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2014',
#      'conference_name': 'ICDCN',
#      'url': 'https://doi.org/10.1007/978-3-642-45249-9_30',
#      'coauthors': ['Chih Wei Ling', 'Anwitaman Datta']},
#     {'title': 'Locally Repairable RapidRAID Systematic Codes - One simple convoluted way to get it all.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2014',
#      'conference_name': 'ITW',
#      'url': 'https://doi.org/10.1109/ITW.2014.6970792',
#      'coauthors': ['Anwitaman Datta']}],
#    'Informal and Other Publications': [{'title': 'People are Processors: Coalitional Auctions for Complex Projects.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2014',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1402.2970',
#      'coauthors': ['Piotr Skowron 0001',
#       'Krzysztof Rzadca',
#       'Anwitaman Datta']},
#     {'title': 'Sparsity Exploiting Erasure Coding for Resilient Storage and Efficient I/O Access in Delta based Versioning Systems.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2014',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1411.4762',
#      'coauthors': ['J. Harshan', 'Frédérique E. Oggier', 'Anwitaman Datta']},
#     {'title': 'rPIR: Ramp Secret Sharing based Communication Efficient Private Information Retrieval.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2014',
#      'conference_name': 'IACR Cryptol. ePrint Arch.',
#      'url': 'http://eprint.iacr.org/2014/044',
#      'coauthors': ['Lichun Li', 'Michael Militzer', 'Anwitaman Datta']}]},
#   '2006': {'Conference and Workshop Papers': [{'title': 'Oscar: Small-World Overlay for Realistic Key Distributions.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2006',
#      'conference_name': 'DBISP2P',
#      'url': 'https://doi.org/10.1007/978-3-540-71661-7_25',
#      'coauthors': ['Sarunas Girdzijauskas', 'Anwitaman Datta', 'Karl Aberer']},
#     {'title': 'Optimal Caching for First-Order Query Load-Balancing in Decentralized Index Structures.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2006',
#      'conference_name': 'DBISP2P',
#      'url': 'https://doi.org/10.1007/978-3-540-71661-7_32',
#      'coauthors': ['Anwitaman Datta', 'Wolfgang Nejdl', 'Karl Aberer']},
#     {'title': 'The Challenges of Merging Two Similar Structured Overlays: A Tale of Two Networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2006',
#      'conference_name': 'IWSOS/EuroNGI',
#      'url': 'https://doi.org/10.1007/11822035_3',
#      'coauthors': ['Anwitaman Datta', 'Karl Aberer']},
#     {'title': 'Internet-Scale Storage Systems under Churn -- A Study of the Steady-State using Markov Models.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2006',
#      'conference_name': 'Peer-to-Peer Computing',
#      'url': 'https://doi.org/10.1109/P2P.2006.22',
#      'coauthors': ['Anwitaman Datta', 'Karl Aberer']}]},
#   '2018': {'Reference Works': [{'title': 'Load Balancing in Peer-to-Peer Overlay Networks.',
#      'internal_type': 'incollection - encyclopedia',
#      'type': 'Reference Works',
#      'year': '2018',
#      'conference_name': 'Encyclopedia of Database Systems (2nd ed.)',
#      'url': 'https://doi.org/10.1007/978-1-4614-8265-9_1043',
#      'coauthors': ['Anwitaman Datta']},
#     {'title': 'Peer-to-Peer Storage.',
#      'internal_type': 'incollection - encyclopedia',
#      'type': 'Reference Works',
#      'year': '2018',
#      'conference_name': 'Encyclopedia of Database Systems (2nd ed.)',
#      'url': 'https://doi.org/10.1007/978-1-4614-8265-9_1216',
#      'coauthors': ['Anwitaman Datta']},
#     {'title': 'Computational Trust Models.',
#      'internal_type': 'incollection - encyclopedia',
#      'type': 'Reference Works',
#      'year': '2018',
#      'conference_name': 'Encyclopedia of Social Network Analysis and Mining. 2nd Ed.',
#      'url': 'https://doi.org/10.1007/978-1-4939-7131-2_228',
#      'coauthors': ['Xin Liu 0027', 'Anwitaman Datta', 'Karl Aberer']}],
#    'Journal Articles': [{'title': 'A Case for Distributed Multilevel Storage Infrastructure for Visual Surveillance in Intelligent Transportation Networks.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2018',
#      'conference_name': 'IEEE Internet Comput.',
#      'url': 'https://doi.org/10.1109/MIC.2017.265102316',
#      'coauthors': ['Chih Wei Ling', 'Anwitaman Datta', 'Jun Xu']}],
#    'Conference and Workshop Papers': [{'title': 'EGRET: Extortion Graph Exploration Techniques in the Bitcoin Network.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2018',
#      'conference_name': 'ICDM Workshops',
#      'url': 'https://doi.org/10.1109/ICDMW.2018.00043',
#      'coauthors': ['Silivanxay Phetsouvanh',
#       'Frédérique E. Oggier',
#       'Anwitaman Datta']},
#     {'title': 'BiVA: Bitcoin Network Visualization & Analysis.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2018',
#      'conference_name': 'ICDM Workshops',
#      'url': 'https://doi.org/10.1109/ICDMW.2018.00210',
#      'coauthors': ['Frédérique E. Oggier',
#       'Silivanxay Phetsouvanh',
#       'Anwitaman Datta']},
#     {'title': 'Entropic Centrality for non-atomic Flow Networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2018',
#      'conference_name': 'ISITA',
#      'url': 'https://doi.org/10.23919/ISITA.2018.8664236',
#      'coauthors': ['Frédérique E. Oggier',
#       'Silivanxay Phetsouvanh',
#       'Anwitaman Datta']},
#     {'title': 'Entropy-based Graph Clustering - A Simulated Annealing Approach.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2018',
#      'conference_name': 'ISITA',
#      'url': 'https://doi.org/10.23919/ISITA.2018.8664249',
#      'coauthors': ['Frédérique E. Oggier',
#       'Silivanxay Phetsouvanh',
#       'Anwitaman Datta']},
#     {'title': 'Worth its Weight in Likes: Towards Detecting Fake Likes on Instagram.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2018',
#      'conference_name': 'WebSci',
#      'url': 'https://doi.org/10.1145/3201064.3201105',
#      'coauthors': ['Indira Sen',
#       'Anupama Aggarwal',
#       'Shiven Mian',
#       'Siddharth Singh',
#       'Ponnurangam Kumaraguru',
#       'Anwitaman Datta']}]},
#   '2004': {'Journal Articles': [{'title': 'Efficient, Self-Contained Handling of Identity in Peer-to-Peer Systems.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2004',
#      'conference_name': 'IEEE Trans. Knowl. Data Eng.',
#      'url': 'https://doi.org/10.1109/TKDE.2004.1318567',
#      'coauthors': ['Karl Aberer', 'Anwitaman Datta', 'Manfred Hauswirth']}],
#    'Conference and Workshop Papers': [{'title': 'A Query-Adaptive Partial Distributed Hash Table for Peer-to-Peer Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2004',
#      'conference_name': 'EDBT Workshops',
#      'url': 'https://doi.org/10.1007/978-3-540-30192-9_50',
#      'coauthors': ['Fabius Klemm', 'Anwitaman Datta', 'Karl Aberer']},
#     {'title': 'Autonomous Gossiping: A Self-Organizing Epidemic Algorithm for Selective Information Dissemination in Wireless Mobile Ad-Hoc Networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2004',
#      'conference_name': 'ICSNW',
#      'url': 'https://doi.org/10.1007/978-3-540-30145-5_8',
#      'coauthors': ['Anwitaman Datta', 'Silvia Quarteroni', 'Karl Aberer']},
#     {'title': 'On de Bruijn Routing in Distributed Hash Tables: There and Back Again.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2004',
#      'conference_name': 'Peer-to-Peer Computing',
#      'url': 'https://doi.org/10.1109/PTP.2004.1334943',
#      'coauthors': ['Anwitaman Datta',
#       'Sarunas Girdzijauskas',
#       'Karl Aberer']}]},
#   '2005': {'Parts in Books or Collections': [{'title': 'P-Grid: Dynamics of Self-Organizing Processes in Structured Peer-to-Peer Systems.',
#      'internal_type': 'incollection',
#      'type': 'Parts in Books or Collections',
#      'year': '2005',
#      'conference_name': 'Peer-to-Peer Systems and Applications',
#      'url': 'https://doi.org/10.1007/11530657_10',
#      'coauthors': ['Karl Aberer', 'Anwitaman Datta', 'Manfred Hauswirth']}],
#    'Journal Articles': [{'title': 'Das P-Grid-Overlay-Netzwerk: Von einem einfachen Prinzip zu einem komplexen System.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2005',
#      'conference_name': 'Datenbank-Spektrum',
#      'url': 'http://www.datenbank-spektrum.de/v2/archiv/beitrag.html?key=dbspektrum/AbererDHS05&nummer=13',
#      'coauthors': ['Karl Aberer',
#       'Anwitaman Datta',
#       'Manfred Hauswirth',
#       'Roman Schmidt']},
#     {'title': 'A decentralised public key infrastructure for customer-to-customer e-commerce.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2005',
#      'conference_name': 'Int. J. Bus. Process. Integr. Manag.',
#      'url': 'https://doi.org/10.1504/IJBPIM.2005.006962',
#      'coauthors': ['Karl Aberer', 'Anwitaman Datta', 'Manfred Hauswirth']}],
#    'Conference and Workshop Papers': [{'title': 'Multifaceted Simultaneous Load Balancing in DHT-Based P2P Systems: A New Game with Old Balls and Bins.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2005',
#      'conference_name': 'Self-star Properties in Complex Information Systems',
#      'url': 'https://doi.org/10.1007/11428589_24',
#      'coauthors': ['Karl Aberer', 'Anwitaman Datta', 'Manfred Hauswirth']},
#     {'title': 'Stochasticity of probabilistic systems: analysis methodologies case-study.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2005',
#      'conference_name': 'CollaborateCom',
#      'url': 'https://doi.org/10.1109/COLCOM.2005.1651267',
#      'coauthors': ['Anwitaman Datta', 'Martin Hasler', 'Karl Aberer']},
#     {'title': 'On Small World Graphs in Non-uniformly Distributed Key Spaces.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2005',
#      'conference_name': 'ICDE Workshops',
#      'url': 'https://doi.org/10.1109/ICDE.2005.254',
#      'coauthors': ['Sarunas Girdzijauskas', 'Anwitaman Datta', 'Karl Aberer']},
#     {'title': 'Range Queries in Trie-Structured Overlays.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2005',
#      'conference_name': 'Peer-to-Peer Computing',
#      'url': 'https://doi.org/10.1109/P2P.2005.31',
#      'coauthors': ['Anwitaman Datta',
#       'Manfred Hauswirth',
#       'Renault John',
#       'Roman Schmidt',
#       'Karl Aberer']},
#     {'title': 'Indexing Data-oriented Overlay Networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2005',
#      'conference_name': 'VLDB',
#      'url': 'http://www.vldb.org/archives/website/2005/program/paper/thu/p685-aberer.pdf',
#      'coauthors': ['Karl Aberer',
#       'Anwitaman Datta',
#       'Manfred Hauswirth',
#       'Roman Schmidt']}]},
#   '2021': {'Journal Articles': [{'title': 'Utility-Driven k-Anonymization of Public Transport User Data.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2021',
#      'conference_name': 'IEEE Access',
#      'url': 'https://doi.org/10.1109/ACCESS.2021.3055505',
#      'coauthors': ['Bhawani Shanker Bhati',
#       'Jordan Ivanchev',
#       'Iva Bojic',
#       'Anwitaman Datta',
#       'David Eckhoff']},
#     {'title': 'QLOC: Quorums With Local Reconstruction Codes.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2021',
#      'conference_name': 'IEEE Access',
#      'url': 'https://doi.org/10.1109/ACCESS.2021.3093450',
#      'coauthors': ['Anwitaman Datta',
#       'Adamas Aqsa Fahreza',
#       'Frédérique E. Oggier']},
#     {'title': 'Analysis of multi-input multi-output transactions in the Bitcoin network.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2021',
#      'conference_name': 'Concurr. Comput. Pract. Exp.',
#      'url': 'https://doi.org/10.1002/cpe.5629',
#      'coauthors': ['Silivanxay Phetsouvanh',
#       'Anwitaman Datta',
#       'Frédérique E. Oggier']},
#     {'title': 'On Grid Quorums for Erasure Coded Data.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2021',
#      'conference_name': 'Entropy',
#      'url': 'https://doi.org/10.3390/e23020177',
#      'coauthors': ['Frédérique E. Oggier', 'Anwitaman Datta']},
#     {'title': 'On unlinkability and denial of service attacks resilience of whistleblower platforms.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2021',
#      'conference_name': 'Future Gener. Comput. Syst.',
#      'url': 'https://doi.org/10.1016/j.future.2021.01.030',
#      'coauthors': ['Silivanxay Phetsouvanh', 'Anwitaman Datta', 'Alwen Tiu']},
#     {'title': 'Renyi entropy driven hierarchical graph clustering.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2021',
#      'conference_name': 'PeerJ Comput. Sci.',
#      'url': 'https://doi.org/10.7717/peerj-cs.366',
#      'coauthors': ['Frédérique E. Oggier', 'Anwitaman Datta']},
#     {'title': 'Centrality informed embedding of networks for temporal feature extraction.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2021',
#      'conference_name': 'Soc. Netw. Anal. Min.',
#      'url': 'https://doi.org/10.1007/s13278-021-00720-8',
#      'coauthors': ['Frédérique E. Oggier', 'Anwitaman Datta']}],
#    'Informal and Other Publications': [{'title': 'Misleading the Covid-19 vaccination discourse on Twitter: An exploratory study of infodemic around the pandemic.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2021',
#      'conference_name': 'CoRR',
#      'url': 'https://arxiv.org/abs/2108.10735',
#      'coauthors': ['Shakshi Sharma', 'Rajesh Sharma', 'Anwitaman Datta']},
#     {'title': 'A Modular Framework for Centrality and Clustering in Complex Networks.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2021',
#      'conference_name': 'CoRR',
#      'url': 'https://arxiv.org/abs/2111.11623',
#      'coauthors': ['Frédérique E. Oggier',
#       'Silivanxay Phetsouvanh',
#       'Anwitaman Datta']}]},
#   '2003': {'Journal Articles': [{'title': 'Separating Business Process from User Interaction in Web-Based Information Commerce.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2003',
#      'conference_name': 'Electron. Commer. Res.',
#      'url': 'https://doi.org/10.1023/A:1021529411332',
#      'coauthors': ['Karl Aberer',
#       'Anwitaman Datta',
#       'Zoran Despotovic',
#       'Andreas Wombacher']},
#     {'title': 'Advanced Peer-to-Peer Networking: The P-Grid System and its Applications.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2003',
#      'conference_name': 'Prax. Inf.verarb. Kommun.',
#      'url': 'https://doi.org/10.1515/PIKO.2003.86',
#      'coauthors': ['Karl Aberer',
#       'Philippe Cudré-Mauroux',
#       'Anwitaman Datta',
#       'Zoran Despotovic',
#       'Manfred Hauswirth',
#       'Magdalena Punceva',
#       'Roman Schmidt',
#       'Jie Wu 0012']},
#     {'title': 'P-Grid: a self-organizing structured P2P system.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2003',
#      'conference_name': 'SIGMOD Rec.',
#      'url': 'https://doi.org/10.1145/945721.945729',
#      'coauthors': ['Karl Aberer',
#       'Philippe Cudré-Mauroux',
#       'Anwitaman Datta',
#       'Zoran Despotovic',
#       'Manfred Hauswirth',
#       'Magdalena Punceva',
#       'Roman Schmidt']}],
#    'Conference and Workshop Papers': [{'title': 'PIX-Grid: A Platform for P2P Photo Exchange.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2003',
#      'conference_name': 'CAiSE Workshops',
#      'url': 'https://ceur-ws.org/Vol-75/files/UMICS_17.pdf',
#      'coauthors': ['Karl Aberer',
#       'Philippe Cudré-Mauroux',
#       'Anwitaman Datta',
#       'Manfred Hauswirth']},
#     {'title': 'Handling Identity in Peer-to-Peer Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2003',
#      'conference_name': 'DEXA Workshops',
#      'url': 'https://doi.org/10.1109/DEXA.2003.1232142',
#      'coauthors': ['Manfred Hauswirth', 'Anwitaman Datta', 'Karl Aberer']},
#     {'title': 'Updates in Highly Unreliable, Replicated Peer-to-Peer Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2003',
#      'conference_name': 'ICDCS',
#      'url': 'https://doi.org/10.1109/ICDCS.2003.1203454',
#      'coauthors': ['Anwitaman Datta', 'Manfred Hauswirth', 'Karl Aberer']},
#     {'title': 'Beyond "web of trust": Enabling P2P E-commerce.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2003',
#      'conference_name': 'CEC',
#      'url': 'https://doi.org/10.1109/COEC.2003.1210265',
#      'coauthors': ['Anwitaman Datta', 'Manfred Hauswirth', 'Karl Aberer']},
#     {'title': 'On Optimal Update Policies and Cluster Sizes for 2-Tier Distributed Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2003',
#      'conference_name': 'WETICE',
#      'url': 'https://doi.org/10.1109/ENABL.2003.1231390',
#      'coauthors': ['Prasenjit Dey', 'Anwitaman Datta']}]},
#   '2017': {'Journal Articles': [{'title': 'Cooperation and Competition When Bidding for Complex Projects: Centralized and Decentralized Perspectives.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2017',
#      'conference_name': 'IEEE Intell. Syst.',
#      'url': 'https://doi.org/10.1109/MIS.2017.4',
#      'coauthors': ['Piotr Skowron 0001',
#       'Krzysztof Rzadca',
#       'Anwitaman Datta']},
#     {'title': 'Write-only oblivious RAM-based privacy-preserved access of outsourced data.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2017',
#      'conference_name': 'Int. J. Inf. Sec.',
#      'url': 'https://doi.org/10.1007/s10207-016-0329-x',
#      'coauthors': ['Lichun Li', 'Anwitaman Datta']},
#     {'title': 'rPIR: ramp secret sharing-based communication-efficient private information retrieval.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2017',
#      'conference_name': 'Int. J. Inf. Sec.',
#      'url': 'https://doi.org/10.1007/s10207-016-0347-8',
#      'coauthors': ['Lichun Li', 'Michael Militzer', 'Anwitaman Datta']},
#     {'title': 'On query result integrity over encrypted data.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2017',
#      'conference_name': 'Inf. Process. Lett.',
#      'url': 'https://doi.org/10.1016/j.ipl.2017.02.005',
#      'coauthors': ['Ertem Esiner', 'Anwitaman Datta']}],
#    'Conference and Workshop Papers': [{'title': 'Lilliput: A Storage Service for Lightweight Peer-to-Peer Online Social Networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2017',
#      'conference_name': 'ICCCN',
#      'url': 'https://doi.org/10.1109/ICCCN.2017.8038443',
#      'coauthors': ['Thomas Paul',
#       'Niklas Lochschmidt',
#       'Hani Salah',
#       'Anwitaman Datta',
#       'Thorsten Strufe']},
#     {'title': 'Data Integrity for Collaborative Applications over Hosted Services.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2017',
#      'conference_name': 'ICDCS',
#      'url': 'https://doi.org/10.1109/ICDCS.2017.316',
#      'coauthors': ['Ertem Esiner', 'Anwitaman Datta']}]},
#   '2008': {'Journal Articles': [{'title': 'Stochastic analysis of the interplay between object maintenance and churn.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2008',
#      'conference_name': 'Comput. Commun.',
#      'url': 'https://doi.org/10.1016/j.comcom.2007.08.008',
#      'coauthors': ['Di Wu 0001',
#       'Ye Tian 0004',
#       'Kam-Wing Ng',
#       'Anwitaman Datta']}],
#    'Conference and Workshop Papers': [{'title': 'Classification in P2P Networks by Bagging Cascade RSVMs.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2008',
#      'conference_name': 'DBISP2P',
#      'url': 'http://www.vldb.org/conf/2008/workshops/WProc_dbisp2p08/Paper_19.pdf',
#      'coauthors': ['Hock Hee Ang',
#       'Vivekanand Gopalkrishnan',
#       'Steven C. H. Hoi',
#       'Wee Keong Ng',
#       'Anwitaman Datta']},
#     {'title': 'On Visualizing Heterogeneous Semantic Networks from Multiple Data Sources.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2008',
#      'conference_name': 'ICADL',
#      'url': 'https://doi.org/10.1007/978-3-540-89533-6_27',
#      'coauthors': ['Maureen',
#       'Aixin Sun',
#       'Ee-Peng Lim',
#       'Anwitaman Datta',
#       'Kuiyu Chang']},
#     {'title': 'WikiNetViz: Visualizing friends and adversaries in implicit social networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2008',
#      'conference_name': 'ISI',
#      'url': 'https://doi.org/10.1109/ISI.2008.4565029',
#      'coauthors': ['Minh-Tam Le',
#       'Hoang-Vu Dang',
#       'Ee-Peng Lim',
#       'Anwitaman Datta']},
#     {'title': 'Really Simple Security for P2P Dissemination of Really Simple Syndication.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2008',
#      'conference_name': 'OTM Workshops',
#      'url': 'https://doi.org/10.1007/978-3-540-88875-8_8',
#      'coauthors': ['Anwitaman Datta', 'Xin Liu 0027']}]},
#   '2016': {'Journal Articles': [{'title': 'A study of the performance of novel storage-centric repairable codes.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2016',
#      'conference_name': 'Computing',
#      'url': 'https://doi.org/10.1007/s00607-015-0468-3',
#      'coauthors': ['Anwitaman Datta',
#       'Lluis Pamies-Juarez',
#       'Frédérique E. Oggier']},
#     {'title': 'Sparsity exploiting erasure coding for distributed storage of versioned data.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2016',
#      'conference_name': 'Computing',
#      'url': 'https://doi.org/10.1007/s00607-016-0485-x',
#      'coauthors': ['J. Harshan', 'Frédérique E. Oggier', 'Anwitaman Datta']},
#     {'title': 'Auditable versioned data storage outsourcing.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2016',
#      'conference_name': 'Future Gener. Comput. Syst.',
#      'url': 'https://doi.org/10.1016/j.future.2015.08.001',
#      'coauthors': ['Ertem Esiner', 'Anwitaman Datta']},
#     {'title': 'DiVers: An erasure code based storage architecture for versioning exploiting sparsity.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2016',
#      'conference_name': 'Future Gener. Comput. Syst.',
#      'url': 'https://doi.org/10.1016/j.future.2016.01.005',
#      'coauthors': ['J. Harshan', 'Anwitaman Datta', 'Frédérique E. Oggier']},
#     {'title': 'Privacy-Preserving-Outsourced Association Rule Mining on Vertically Partitioned Databases.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2016',
#      'conference_name': 'IEEE Trans. Inf. Forensics Secur.',
#      'url': 'https://doi.org/10.1109/TIFS.2016.2561241',
#      'coauthors': ['Lichun Li',
#       'Rongxing Lu',
#       'Kim-Kwang Raymond Choo',
#       'Anwitaman Datta',
#       'Jun Shao 0001']},
#     {'title': 'Differential Erasure Codes for Efficient Archival of Versioned Data in Cloud Storage Systems.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2016',
#      'conference_name': 'Trans. Large Scale Data Knowl. Centered Syst.',
#      'url': 'https://doi.org/10.1007/978-3-662-54054-1_2',
#      'coauthors': ['J. Harshan', 'Anwitaman Datta', 'Frédérique E. Oggier']}],
#    'Conference and Workshop Papers': [{'title': 'Layered security for storage at the edge: on decentralized multi-factor access control.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2016',
#      'conference_name': 'ICDCN',
#      'url': 'https://doi.org/10.1145/2833312.2833452',
#      'coauthors': ['Ertem Esiner', 'Anwitaman Datta']},
#     {'title': 'DMZtore: A dispersed Data Storage System with Decentralized Multi-factor Access Control (Demo).',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2016',
#      'conference_name': 'ICDCS',
#      'url': 'https://doi.org/10.1109/ICDCS.2016.42',
#      'coauthors': ['Ertem Esiner', 'Shun Hanli Hanley', 'Anwitaman Datta']},
#     {'title': 'Elastic Erasure Coding for Adaptive Redundancy.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2016',
#      'conference_name': 'ICDCS Workshops',
#      'url': 'https://doi.org/10.1109/ICDCSW.2016.23',
#      'coauthors': ['Wan-Hee Cho', 'Anwitaman Datta']},
#     {'title': 'SwiftER: Elastic Erasure Coded Storage System.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2016',
#      'conference_name': 'SRDS',
#      'url': 'https://doi.org/10.1109/SRDS.2016.040',
#      'coauthors': ['Anwitaman Datta', 'Wan-Hee Cho']}]},
#   '2010': {'Parts in Books or Collections': [{'title': 'Information Integration for Graph Databases.',
#      'internal_type': 'incollection',
#      'type': 'Parts in Books or Collections',
#      'year': '2010',
#      'conference_name': 'Link Mining',
#      'url': 'https://doi.org/10.1007/978-1-4419-6515-8_10',
#      'coauthors': ['Ee-Peng Lim',
#       'Aixin Sun',
#       'Anwitaman Datta',
#       'Kuiyu Chang']},
#     {'title': 'Decentralized Online Social Networks.',
#      'internal_type': 'incollection',
#      'type': 'Parts in Books or Collections',
#      'year': '2010',
#      'conference_name': 'Handbook of Social Network Technologies',
#      'url': 'https://doi.org/10.1007/978-1-4419-7142-5_17',
#      'coauthors': ['Anwitaman Datta',
#       'Sonja Buchegger',
#       'Le-Hung Vu',
#       'Thorsten Strufe',
#       'Krzysztof Rzadca']},
#     {'title': 'Interdisciplinary Matchmaking: Choosing Collaborators by Skill, Acquaintance and Trust.',
#      'internal_type': 'incollection',
#      'type': 'Parts in Books or Collections',
#      'year': '2010',
#      'conference_name': 'Computational Social Network Analysis ',
#      'url': 'https://doi.org/10.1007/978-1-84882-229-0_12',
#      'coauthors': ['Albert Hupa',
#       'Krzysztof Rzadca',
#       'Adam Wierzbicki',
#       'Anwitaman Datta']}],
#    'Journal Articles': [{'title': 'Multi-objective optimization of multicast overlays for collaborative applications.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2010',
#      'conference_name': 'Comput. Networks',
#      'url': 'https://doi.org/10.1016/j.comnet.2010.05.018',
#      'coauthors': ['Krzysztof Rzadca',
#       'Jackson Tan Teck Yong',
#       'Anwitaman Datta']},
#     {'title': 'Structured overlay for heterogeneous environments: Design and evaluation of oscar.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2010',
#      'conference_name': 'ACM Trans. Auton. Adapt. Syst.',
#      'url': 'https://doi.org/10.1145/1671948.1671950',
#      'coauthors': ['Sarunas Girdzijauskas',
#       'Anwitaman Datta',
#       'Karl Aberer']}],
#    'Conference and Workshop Papers': [{'title': 'SoJa: Collaborative reference management using a decentralized social information system.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'CollaborateCom',
#      'url': 'https://doi.org/10.4108/icst.collaboratecom.2010.32',
#      'coauthors': ['Anwitaman Datta']},
#     {'title': 'On trust guided collaboration among cloud service providers.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'CollaborateCom',
#      'url': 'https://doi.org/10.4108/icst.trustcol.2010.6',
#      'coauthors': ['Xin Liu 0027', 'Anwitaman Datta']},
#     {'title': 'Visualizing and Exploring Evolving Information Networks in Wikipedia.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'ICADL',
#      'url': 'https://doi.org/10.1007/978-3-642-13654-2_7',
#      'coauthors': ['Ee-Peng Lim',
#       'Agus Trisnajaya Kwee',
#       'Nelman Lubis Ibrahim',
#       'Aixin Sun',
#       'Anwitaman Datta',
#       'Kuiyu Chang',
#       'Maureen']},
#     {'title': 'Replica Placement in P2P Storage: Complexity and Game Theoretic Analyses.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'ICDCS',
#      'url': 'https://doi.org/10.1109/ICDCS.2010.67',
#      'coauthors': ['Krzysztof Rzadca', 'Anwitaman Datta', 'Sonja Buchegger']},
#     {'title': 'COBS: A tool for collaborative browsing and search on the web.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'ICME',
#      'url': 'https://doi.org/10.1109/ICME.2010.5583207',
#      'coauthors': ['Christian von der Weth',
#       'Anwitaman Datta',
#       'Sally Nanyang Ang']},
#     {'title': 'SharedMind: A tool for collaborative mind-mapping.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'ICME',
#      'url': 'https://doi.org/10.1109/ICME.2010.5583200',
#      'coauthors': ['Sally Ang', 'Krzysztof Rzadca', 'Anwitaman Datta']},
#     {'title': 'Do Wikipedians follow domain experts?: a domain-specific study on Wikipedia knowledge building.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'JCDL',
#      'url': 'https://doi.org/10.1145/1816123.1816141',
#      'coauthors': ['Yi Zhang',
#       'Aixin Sun',
#       'Anwitaman Datta',
#       'Kuiyu Chang',
#       'Ee-Peng Lim']},
#     {'title': 'Satrap: Data and Network Heterogeneity Aware P2P Data-Mining.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'PAKDD (2)',
#      'url': 'https://doi.org/10.1007/978-3-642-13672-6_7',
#      'coauthors': ['Hock Hee Ang',
#       'Vivekanand Gopalkrishnan',
#       'Anwitaman Datta',
#       'Wee Keong Ng',
#       'Steven C. H. Hoi']},
#     {'title': 'Learning About the Quality of Teamwork from Wikiteams.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2010',
#      'conference_name': 'SocialCom/PASSAT',
#      'url': 'https://doi.org/10.1109/SocialCom.2010.13',
#      'coauthors': ['Piotr Turek',
#       'Adam Wierzbicki',
#       'Radoslaw Nielek',
#       'Albert Hupa',
#       'Anwitaman Datta']},
# ...
#      'coauthors': ['Chenliang Li', 'Aixin Sun', 'Anwitaman Datta']},
#     {'title': 'GoDisco++: A gossip algorithm for information dissemination in multi-dimensional community networks.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2013',
#      'conference_name': 'Pervasive Mob. Comput.',
#      'url': 'https://doi.org/10.1016/j.pmcj.2012.09.005',
#      'coauthors': ['Rajesh Sharma', 'Anwitaman Datta']},
#     {'title': 'An overview of codes tailor-made for better repairability in networked distributed storage systems.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2013',
#      'conference_name': 'SIGACT News',
#      'url': 'https://doi.org/10.1145/2447712.2447735',
#      'coauthors': ['Anwitaman Datta', 'Frédérique E. Oggier']},
#     {'title': 'Editorial.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2013',
#      'conference_name': 'Soc. Netw. Anal. Min.',
#      'url': 'https://doi.org/10.1007/s13278-013-0145-5',
#      'coauthors': ['Anwitaman Datta', 'Ee-Peng Lim', 'Stuart W. Shulman']}],
#    'Conference and Workshop Papers': [{'title': 'Efficient updates in cross-object erasure-coded storage systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'IEEE BigData',
#      'url': 'https://doi.org/10.1109/BigData.2013.6691658',
#      'coauthors': ['Kyumars Sheykh Esmaili',
#       'Aatish Chiniah',
#       'Anwitaman Datta']},
#     {'title': 'CORE: Cross-object redundancy for efficient data repair in storage systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'IEEE BigData',
#      'url': 'https://doi.org/10.1109/BigData.2013.6691581',
#      'coauthors': ['Kyumars Sheykh Esmaili',
#       'Lluis Pamies-Juarez',
#       'Anwitaman Datta']},
#     {'title': 'Data Insertion and Archiving in Erasure-Coding Based Large-Scale Storage Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'ICDCIT',
#      'url': 'https://doi.org/10.1007/978-3-642-36071-8_4',
#      'coauthors': ['Lluis Pamies-Juarez',
#       'Frédérique E. Oggier',
#       'Anwitaman Datta']},
#     {'title': 'Decentralized Erasure Coding for Efficient Data Archival in Distributed Storage Systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'ICDCN',
#      'url': 'https://doi.org/10.1007/978-3-642-35668-1_4',
#      'coauthors': ['Lluis Pamies-Juarez',
#       'Frédérique E. Oggier',
#       'Anwitaman Datta']},
#     {'title': 'RapidRAID: Pipelined erasure codes for fast data archival in distributed storage systems.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'INFOCOM',
#      'url': 'https://doi.org/10.1109/INFCOM.2013.6566922',
#      'coauthors': ['Lluis Pamies-Juarez',
#       'Anwitaman Datta',
#       'Frédérique E. Oggier']},
#     {'title': 'Towards secure outsourcing of collaborative sensing and analytic applications to the cloud - the pCloud approach.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'MCS@Middleware',
#      'url': 'https://doi.org/10.1145/2541603.2541606',
#      'coauthors': ['Tien Tuan Anh Dinh', 'Anwitaman Datta']},
#     {'title': 'Storage codes: Managing big data with small overheads.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'NetCod',
#      'url': 'https://doi.org/10.1109/NetCod.2013.6570839',
#      'coauthors': ['Anwitaman Datta', 'Frédérique E. Oggier']},
#     {'title': 'A Framework for Trust-Based Multidisciplinary Team Recommendation.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2013',
#      'conference_name': 'UMAP',
#      'url': 'https://doi.org/10.1007/978-3-642-38844-6_4',
#      'coauthors': ['Lorenzo Bossi',
#       'Stefano Braghin',
#       'Anwitaman Datta',
#       'Alberto Trombetta']}],
#    'Informal and Other Publications': [{'title': 'The CORE Storage Primitive: Cross-Object Redundancy for Efficient Data Repair & Access in Erasure Coded Storage',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2013',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1302.5192',
#      'coauthors': ['Kyumars Sheykh Esmaili',
#       'Lluis Pamies-Juarez',
#       'Anwitaman Datta']},
#     {'title': 'The Zen of Multidisciplinary Team Recommendation',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2013',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1303.0646',
#      'coauthors': ['Anwitaman Datta',
#       'Stefano Braghin',
#       'Jackson Tan Teck Yong']},
#     {'title': 'Streamforce: outsourcing access control enforcement for stream data to the clouds',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2013',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1305.6146',
#      'coauthors': ['Tien Tuan Anh Dinh', 'Anwitaman Datta']},
#     {'title': 'On the Effectiveness of Polynomial Realization of Reed-Solomon Codes for Storage Systems.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2013',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1312.5155',
#      'coauthors': ['Kyumars Sheykh Esmaili', 'Anwitaman Datta']},
#     {'title': 'Write-Only Oblivious RAM based Privacy-Preserved Access of Outsourced Data.',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2013',
#      'conference_name': 'IACR Cryptol. ePrint Arch.',
#      'url': 'http://eprint.iacr.org/2013/694',
#      'coauthors': ['Lichun Li', 'Anwitaman Datta']}]},
#   '2012': {'Journal Articles': [{'title': 'Merging ring-structured overlay indices: toward network-data transparency.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2012',
#      'conference_name': 'Computing',
#      'url': 'https://doi.org/10.1007/s00607-012-0201-4',
#      'coauthors': ['Anwitaman Datta']},
#     {'title': 'The Blind Enforcer: On Fine-Grained Access Control Enforcement on Untrusted Clouds.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2012',
#      'conference_name': 'IEEE Data Eng. Bull.',
#      'url': 'http://sites.computer.org/debull/A12dec/blind.pdf',
#      'coauthors': ['Tien Tuan Anh Dinh', 'Anwitaman Datta']},
#     {'title': 'City on the Sky: Extending XACML for Flexible, Secure Data Sharing on the Cloud.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2012',
#      'conference_name': 'J. Grid Comput.',
#      'url': 'https://doi.org/10.1007/s10723-012-9212-9',
#      'coauthors': ['Tien Tuan Anh Dinh', 'Wenqiang Wang', 'Anwitaman Datta']},
#     {'title': 'Multiterm Keyword Search in NoSQL Systems.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2012',
#      'conference_name': 'IEEE Internet Comput.',
#      'url': 'https://doi.org/10.1109/MIC.2011.140',
#      'coauthors': ['Christian von der Weth', 'Anwitaman Datta']},
#     {'title': 'Infrastructures for Online Social Networking Services [Guest editorial].',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2012',
#      'conference_name': 'IEEE Internet Comput.',
#      'url': 'https://doi.org/10.1109/MIC.2012.53',
#      'coauthors': ['Anwitaman Datta',
#       'Marios D. Dikaiakos',
#       'Seif Haridi',
#       'Liviu Iftode']},
#     {'title': 'Contextual Trust Aided Enhancement of Data Availability in Peer-to-Peer Backup Storage Systems.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2012',
#      'conference_name': 'J. Netw. Syst. Manag.',
#      'url': 'https://doi.org/10.1007/s10922-011-9198-9',
#      'coauthors': ['Xin Liu 0027', 'Anwitaman Datta']},
#     {'title': 'Mining latent relations in peer-production environments: a case study with Wikipedia article similarity and controversy.',
#      'internal_type': 'article',
#      'type': 'Journal Articles',
#      'year': '2012',
#      'conference_name': 'Soc. Netw. Anal. Min.',
#      'url': 'https://doi.org/10.1007/s13278-011-0037-5',
#      'coauthors': ['Chenliang Li', 'Anwitaman Datta', 'Aixin Sun']}],
#    'Conference and Workshop Papers': [{'title': 'Modeling Context Aware Dynamic Trust Using Hidden Markov Model.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'AAAI',
#      'url': 'https://doi.org/10.1609/aaai.v26i1.8395',
#      'coauthors': ['Xin Liu 0027', 'Anwitaman Datta']},
#     {'title': 'Redundantly grouped cross-object coding for repairable storage.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'APSys',
#      'url': 'https://doi.org/10.1145/2349896.2349898',
#      'coauthors': ['Anwitaman Datta', 'Frédérique E. Oggier']},
#     {'title': 'A Tunable Graph Model for Incorporating Geographic Spread in Social Graph Models.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'ASONAM',
#      'url': 'https://doi.org/10.1109/ASONAM.2012.57',
#      'coauthors': ['Rajesh Sharma', 'Anwitaman Datta']},
#     {'title': 'Twevent: segment-based event detection from tweets.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'CIKM',
#      'url': 'https://doi.org/10.1145/2396761.2396785',
#      'coauthors': ['Chenliang Li', 'Aixin Sun', 'Anwitaman Datta']},
#     {'title': 'SuperNova: Super-peers based architecture for decentralized online social networks.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'COMSNETS',
#      'url': 'https://doi.org/10.1109/COMSNETS.2012.6151349',
#      'coauthors': ['Rajesh Sharma', 'Anwitaman Datta']},
#     {'title': 'DRank: Decentralized ranking mechanism for semantic community overlays.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'COMSNETS',
#      'url': 'https://doi.org/10.1109/COMSNETS.2012.6151352',
#      'coauthors': ['Rajesh Sharma', 'Anwitaman Datta']},
#     {'title': 'Topic 7: Peer to Peer Computing.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'Euro-Par',
#      'url': 'https://doi.org/10.1007/978-3-642-32820-6_36',
#      'coauthors': ['Alberto Montresor',
#       'Evaggelia Pitoura',
#       'Anwitaman Datta',
#       'Spyros Voulgaris']},
#     {'title': 'Decentralized Information Dissemination in Multidimensional Semantic Social Overlays.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'ICDCN',
#      'url': 'https://doi.org/10.1007/978-3-642-25959-3_35',
#      'coauthors': ['Rajesh Sharma', 'Anwitaman Datta']},
#     {'title': 'SWAT: Social Web Application for Team Recommendation.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'ICPADS',
#      'url': 'https://doi.org/10.1109/ICPADS.2012.138',
#      'coauthors': ['Stefano Braghin',
#       'Jackson Tan Teck Yong',
#       'Anthony Ventresque',
#       'Anwitaman Datta']},
#     {'title': 'Cloud and the City: Facilitating Flexible Access Control over Data-Streams.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'Secure Data Management',
#      'url': 'https://doi.org/10.1007/978-3-642-32873-2_5',
#      'coauthors': ['Wenqiang Wang',
#       'Tien Tuan Anh Dinh',
#       'Hock-Beng Lim',
#       'Anwitaman Datta']},
#     {'title': 'TwiNER: named entity recognition in targeted twitter stream.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'SIGIR',
#      'url': 'https://doi.org/10.1145/2348283.2348380',
#      'coauthors': ['Chenliang Li',
#       'Jianshu Weng',
#       'Qi He 0002',
#       'Yuxia Yao',
#       'Anwitaman Datta',
#       'Aixin Sun',
#       'Bu-Sung Lee']},
#     {'title': "Detecting Imprudence of 'Reliable' Sellers in Online Auction Sites.",
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2012',
#      'conference_name': 'TrustCom',
#      'url': 'https://doi.org/10.1109/TrustCom.2012.123',
#      'coauthors': ['Xin Liu 0027',
#       'Anwitaman Datta',
#       'Hui Fang 0002',
#       'Jie Zhang 0002']}],
#    'Informal and Other Publications': [{'title': 'Cloud and the City: Facilitating Flexible Access Control over Data Streams',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2012',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1205.6349',
#      'coauthors': ['Wenqiang Wang',
#       'Tien Tuan Anh Dinh',
#       'Hock-Beng Lim',
#       'Anwitaman Datta']},
#     {'title': 'PriSM: A Private Social Mesh for Leveraging Social Networking at Workplace',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2012',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1206.1653',
#      'coauthors': ['Stefano Braghin',
#       'Jackson Tan Teck Yong',
#       'Rajesh Sharma',
#       'Anwitaman Datta']},
#     {'title': 'Delegated Secure Sum Service for Distributed Data Mining in Multi-Cloud Settings',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2012',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1206.2038',
#      'coauthors': ['Tien Tuan Anh Dinh',
#       'Quach Vinh Thanh',
#       'Anwitaman Datta']},
#     {'title': 'An Empirical Study of the Repair Performance of Novel Coding Schemes for Networked Distributed Storage Systems',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2012',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1206.2187',
#      'coauthors': ['Lluis Pamies-Juarez',
#       'Frédérique E. Oggier',
#       'Anwitaman Datta']},
#     {'title': 'RapidRAID: Pipelined Erasure Codes for Fast Data Archival in Distributed Storage Systems',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2012',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1207.6744',
#      'coauthors': ['Lluis Pamies-Juarez',
#       'Anwitaman Datta',
#       'Frédérique E. Oggier']},
#     {'title': 'Stream on the Sky: Outsourcing Access Control Enforcement for Stream Data to the Cloud',
#      'internal_type': 'article - informal',
#      'type': 'Informal and Other Publications',
#      'year': '2012',
#      'conference_name': 'CoRR',
#      'url': 'http://arxiv.org/abs/1210.0660',
#      'coauthors': ['Tien Tuan Anh Dinh', 'Anwitaman Datta']}]},
#   '2002': {'Conference and Workshop Papers': [{'title': 'Separating Business Process from User Interaction Utilizing Process-Aware XSLT Style-Sheets.',
#      'internal_type': 'inproceedings',
#      'type': 'Conference and Workshop Papers',
#      'year': '2002',
#      'conference_name': 'WECWIS',
#      'url': 'https://doi.org/10.1109/WECWIS.2002.1021243',
#      'coauthors': ['Karl Aberer', 'Anwitaman Datta', 'Zoran Despotovic']}]}}}

# %%
years = sorted(map(int, data['publications'].keys()), reverse=True)
